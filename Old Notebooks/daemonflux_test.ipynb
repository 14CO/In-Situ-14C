# %%
from InSitu14CO import Propagator
import numpy as np
import matplotlib.pyplot as plt
import crflux.models as pm
import matplotlib.ticker as ticker
import matplotlib as mpl
import Functions_14CO as F

from tqdm import tqdm

import pandas as pd

from scipy import stats

import daemonflux

# %%
# setup pyplot formatting

axes_style = { 'grid'      : 'True',
               'labelsize' : '14',
               'labelpad'  : '8.0'
             }
grid_style = { 'alpha'     : '0.75',
               'linestyle' : ':' }
font_style = { 'size'      : '10' }

mpl.rc('font', **font_style)
mpl.rc('axes', **axes_style)
mpl.rc('grid', **grid_style)

# %%
Prop = Propagator()

# %%
survival_tensor = F.get_survival_tensor(Prop, N=10**5)
# Out:
# [2025-12-19 13:25:23.812] [TableCreation] [warning] Tables are not available and need to be created. They will be written to '/tmp'. This can take some minutes.
# [2025-12-19 13:25:52.880] [proposal.integral] [warning] Precision 1e-06 has not been reached after 12 steps the value is 7.13000675731052e-08!
# Using now qags! value = 7.103549312051156e-08, abserr = 4.547238658656801e-14, neval = 399, ier = 5
# Running 100000 Simulations at 1.1e-01 GeV...
# ...
# 100%|███████████████████████████████████████████████████████████████████████| 300000/300000 [00:01<00:00, 161220.03it/s]
# Running 100000 Simulations at 1.4e-01 GeV...
# ...
# 100%|███████████████████████████████████████████████████████████████████████| 300002/300002 [00:01<00:00, 163340.97it/s]
# Running 100000 Simulations at 1.8e-01 GeV...
# ...
# 100%|███████████████████████████████████████████████████████████████████████| 300000/300000 [00:01<00:00, 161679.81it/s]
# Running 100000 Simulations at 2.2e-01 GeV...
# ...

# %%
survival_tensor[0,range(85),:,range(85),0]
# Out:
# array([[2.72273386, 2.72273386, 2.72273386, 2.72273386, 2.72273386,
#         2.72273386, 2.72273386, 2.72273386, 2.72273386, 2.72273386],
#        [2.72273386, 2.72273386, 2.72273386, 2.72273386, 2.72273386,
#         2.72273386, 2.72273386, 2.72273386, 2.72273386, 2.72273386],
#        [2.72273386, 2.72273386, 2.72273386, 2.72273386, 2.72273386,
#         2.72273386, 2.72273386, 2.72273386, 2.72273386, 2.72273386],
#        [2.72273386, 2.72273386, 2.72273386, 2.72273386, 2.72273386,
#         2.72273386, 2.72273386, 2.72273386, 2.72273386, 2.72273386],
#        [2.72273386, 2.72273386, 2.72273386, 2.72273386, 2.72273386,
#         2.72273386, 2.72273386, 2.72273386, 2.72273386, 2.72273386],
#        [2.72273386, 2.72273386, 2.72273386, 2.72273386, 2.72273386,
#         2.72273386, 2.72273386, 2.72273386, 2.72273386, 2.72273386],
#        [2.72273386, 2.72273386, 2.72273386, 2.72273386, 2.72273386,
#         2.72273386, 2.72273386, 2.72273386, 2.72273386, 2.72273386],
# ...

# %%
for i in range(9):
    survival_tensor += F.get_survival_tensor(Prop, N=10**5)
survival_tensor /= 10
# Out:
# Running 100000 Simulations at 1.1e-01 GeV...
# ...
# 100%|███████████████████████████████████████████████████████████████████████| 300000/300000 [00:01<00:00, 158799.46it/s]
# Running 100000 Simulations at 1.4e-01 GeV...
# ...
# 100%|███████████████████████████████████████████████████████████████████████| 300000/300000 [00:01<00:00, 157466.29it/s]
# Running 100000 Simulations at 1.8e-01 GeV...
# ...
# 100%|███████████████████████████████████████████████████████████████████████| 300000/300000 [00:01<00:00, 157869.41it/s]
# Running 100000 Simulations at 2.2e-01 GeV...
# ...
# 100%|███████████████████████████████████████████████████████████████████████| 300002/300002 [00:01<00:00, 159845.31it/s]
# Running 100000 Simulations at 2.8e-01 GeV...
# ...
# 100%|███████████████████████████████████████████████████████████████████████| 300006/300006 [00:01<00:00, 157385.51it/s]
# Running 100000 Simulations at 3.5e-01 GeV...
# ...

# %%
np.save('survival_tensor_TEST', survival_tensor)
