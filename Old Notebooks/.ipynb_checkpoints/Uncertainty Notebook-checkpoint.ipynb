# %%
from InSitu14CO import Propagator
import numpy as np
import matplotlib.pyplot as plt
import crflux.models as pm
import matplotlib.ticker as ticker
import matplotlib as mpl
import Functions_14CO as F

from IPython.display import display

from tqdm import tqdm

import pandas as pd

from scipy import stats

from scipy.ndimage import gaussian_filter

import pyunfold as pu

from scipy.io import loadmat
from scipy.interpolate import interp1d

# %%
axes_style = { 'grid'      : 'True',
               'labelsize' : '14',
               'labelpad'  : '8.0'
             }
grid_style = { 'alpha'     : '0.75',
               'linestyle' : ':' }
font_style = { 'size'      : '12' }

mpl.rc('font', **font_style)
mpl.rc('axes', **axes_style)
mpl.rc('grid', **grid_style)

# %%
def T(A):
    return np.swapaxes(A, -2, -1)

# %% [markdown]
# ## Dome C Site Data & Production Rates
#
# We set up a Propagator for the Dome C site and load pre-calculated Production Rates

# %%
site = 'DomeC'
Prop = Propagator()
density_model = ('MSIS00', ('SouthPole', 'January'))

df_Pfast = pd.read_csv('Production Rates/P_fast_DomeC_3233m.csv')
df_Pneg = pd.read_csv('Production Rates/P_neg_DomeC_3233m.csv')
P_14C = np.swapaxes([df_Pfast.T, df_Pneg.T], 0, 1)
model_names = list(df_Pfast.columns)

# The only production model being used is Heisinger
#i = model_names.index('Heisinger')
#prod_cut = np.arange(len(P_14C))[i:i+1]

#Prop.Phi['prod']=P_14C[prod_cut]
#C_flow_response = F.flow_14C_response(Prop)[0]
#C_response = C_flow_response @ Prop.S_mat[Prop.i_start:]

z_samp = Prop.z_samp

# %% [markdown]
# ## Setting Up Time Bins
#
# We separate our time bins into two sections:
#
# Our high-sensitivity region ($\sim$7 kya to present) which affects both Dome C and Taylor Glacier $^{14}$CO levels, and where we use a bin-width of 1 year.
#
# Our low-sensitivity region ($\sim$50 kya to $\sim$7 kya) which only affects the equilibirum level of $^{14}$CO at Taylor Glacier before the start of integration, and where we use a bin-width of 100 years.

# %%
# Dome C Time Bins
dt_DC = Prop.dt_int[0]
t_bins_DC = Prop.t_int_bins-Prop.t_int_bins[-1]
t_DC = Prop.t_int-Prop.t_int_bins[-1]
Period_DC = t_bins_DC[-1]-t_bins_DC[0]

# Taylor Glacier Time Bins
dt_TG_short = 1
dt_TG_long = 100
Period_TG_short = Period_DC
Period_TG = 50000

t_bins_TG_short = -np.flip(np.arange(0, Period_TG_short+dt_TG_short, dt_TG_short)) # time integration steps
t_TG_short = (t_bins_TG_short[:-1]+t_bins_TG_short[1:])/2
t_bins_TG_long = -np.flip(np.arange(-t_bins_TG_short[0], Period_TG+dt_TG_long, dt_TG_long))
t_TG_long = (t_bins_TG_long[:-1]+t_bins_TG_long[1:])/2

t_bins_TG = np.concatenate((t_bins_TG_long[:-1], t_bins_TG_short))
t_TG = (t_bins_TG[:-1]+t_bins_TG[1:])/2
dt_TG = np.diff(t_bins_TG)

# Full Model Time Bins
Period = Period_TG
t_bins = t_bins_TG
t = t_TG
dt = dt_TG

t_scale = t/Period_DC # time scaled from -1 to 0, with 0=present

f_interp_to_DC = ((t_bins[1:].reshape((-1,1))-t_bins_DC[:-1].reshape((1,-1))).clip(0,dt_DC) - (t_bins[:-1].reshape((-1,1))-t_bins_DC[:-1].reshape((1,-1))).clip(0,dt_DC))/dt_DC
f_interp_to_TG = ((t_bins[1:].reshape((-1,1))-t_bins_TG[:-1].reshape((1,-1))).clip(0,dt_TG) - (t_bins[:-1].reshape((-1,1))-t_bins_TG[:-1].reshape((1,-1))).clip(0,dt_TG))/dt_TG

# %% [markdown]
# ## Taylor Glacier Site Data & Production Rates
#
# We set up a Propagator for the Taylor Glacier site and load pre-calculated Production Rates

# %%
# sets the conditions for the study at Taylor Glacier by Dyonisius et al. (https://tc.copernicus.org/articles/17/843/2023/)
rho_ice = 0.92
h_bins = h_bins = np.arange(0, 1001, 1)
Prop_TG = Propagator(pressure=9.248658001389917e+04, # (Pa) pressure used in Taylor Glacier analysis "from LSD ERA reanalysis"
                  elev=526, # (m) elevation listed in Figure 1 caption of Taylor Glacier study (need to confirm)
                  z_grid=h_bins/rho_ice,
                  h_grid=h_bins,
                  rho_ice=rho_ice,
                  z_close=0,
                 ) # (g/cm^3) density used in Taylor Glacier analysis

df_Pfast_TG = pd.read_csv('Production Rates/P_fast_TaylorGlacier_526m.csv')
df_Pneg_TG = pd.read_csv('Production Rates/P_neg_TaylorGlacier_526m.csv')
P_14C_TG = np.swapaxes([df_Pfast_TG.T, df_Pneg_TG.T], 0, 1)
model_names_TG = list(df_Pfast_TG.columns)

# The only production model being used is Heisinger
#i = model_names_TG.index('Heisinger')
#prod_cut_TG = np.arange(len(P_14C_TG))[i:i+1]

#flow = 'sample'
#flowpath = loadmat('matlab/MC_14CO_mod/flowpath_{}.mat'.format(flow))
#age = flowpath['age'][0]

#Prop_TG.Phi['prod']=P_14C_TG[prod_cut_TG]
#C_response_TG, C_init_TG = F.Taylor_flow_response(Prop_TG, flow, t_bins=t_bins_TG)
#C_response_TG = C_response_TG[0,0]
#C_init_TG = C_init_TG[0,0]

TG_data = loadmat('matlab/MC_14CO_mod/TG_data_14CO.mat')
CO_exp_TG_data = TG_data['CO_molec'][3:,0]
CO_err_TG_data = TG_data['CO_molec_err'][3:,0]/2.
z_samp_TG = TG_data['sample_depth_CO'][3:,0]

# %% [markdown]
# ## Propagating Uncertainties in Production
#
# Once we have a suitable contraint on the production rates (ignoring scaling factors), we can calculate a baesian likelihood $L$ by propagating the covariance in the production rates and integrating over the remaining uncertainties with either a grid or MCMC (or some combination of both).
#
# $$\vec{P}_{\mu_f,\mu-,n^0}(h,\alpha) = \sum_E dE\,(N\hat{\sigma}_{190}(\frac{\hat{E}}{190})^\alpha\sum_{\mu^\pm}, \hat{f}_{\text{tot}}\hat{\frac{d}{dh}} \hat{\delta}_{\mu^-}, N\hat{\sigma}_{n^0}\hat{\delta}_{n^0})\, \Phi_{\mu^\pm, n^0}(E,h) = \hat{O}_{msEhh'}(\alpha) \vec{\Phi}_{sEh'}$$
#
# $\vec{\Phi}(E,h)$ - underground energy spectra
#
# $\hat{O}(\alpha)$ - production operator
#
# $\vec{P}_m (h,\alpha)$ - unscaled production rates
#
# $$\Sigma_P(\alpha) = \int \Delta \vec{P}\Delta \vec{P}^Tp(\vec{P}|\alpha) d\vec{P}$$
#
# $\Sigma_p(\alpha)$ - unscaled production rate covariances
#
# $$\vec{f}_{\mu_f, \mu-, n^0} = (\Omega_{CO}\frac{\sigma_{190}}{\hat{\sigma}_{190}}, \Omega_{CO}\frac{f_{\text{tot}}}{\hat{f}_{\text{tot}}}, \Omega_{CO}\frac{P_{n^0}(0)}{\hat{P}_{n^0}(0)})$$
#
# $\Omega_{CO}$ - $^{14}$CO/$^{14}$C ratio
#
# $\vec{f}$ - production rate scale factors
#
# $$\hat{c}_z(\vec{\phi}) = \frac{1}{h_z^+-h_z^-}\int_{h_z^-}^{h_z^+}\int_{t'(h)}^0 \vec{f}\cdot\vec{P}(h'(h,t))\phi(t)e^{\lambda t}\,dt\,dh = \hat{Z}_{zht}\vec{f}_{m}\vec{P}_{mh}\vec{\phi}_t$$
#
# $h_z$ - sample depth bins (+ upper bound, - lower bound)
#
# $h'(h,t)$ - depth at time $t$ of ice parcel w/ present depth $h$
#
# $t'(h)$ - time when ice parcel at depth $h$ began accumulating $^{14}$CO
#
# $\vec{\phi}$ - CR flux history
#
# $\hat{Z}$ - accumulation operator
#
# $$\hat{Z} = \hat{S}\hat{H}e^{\lambda \hat{t}}$$
#
# $\hat{H}$ - accumulation depth interpolation operator (interpolates production depths to h'(h,t))
#
# $$H(h') = (\frac{h'-h_{i-1}}{h_i-h_{i-1}}).\text{clip}(0,1) - (\frac{h'-h_{i}}{h_{i+1}-h_{i}}).\text{clip}(0,1)$$
#
# $h_i$ - propagation depths (for $i$<0 or $i$>max, replace the terms with $h'\geq h_0$ and $h'>h_{\text{max}}$, respectively)
#
# $\hat{S}$ - sample operator (averages over each sample depth range in accumulation depth)
#
# $$S(s,h) = \frac{(s^+ - h^-).\text{clip}(0,\Delta h) - (s^- - h^-).\text{clip}(0,\Delta h)}{\sum_h (s^+ - h^-).\text{clip}(0,\Delta h) - (s^- - h^-).\text{clip}(0,\Delta h)}$$
#
# $s$ - sample depth bins (+ upper bound, - lower bound)
#
# $h$ - accumulation depth bins (- lower bound, $\Delta$ width)
#
# $\hat{c}_z(\vec{\phi})$ - predicted $^{14}$CO concentrations
#
# $$\Sigma_{\hat{c}}(\vec{\phi},\alpha, \vec{f}, \hat{Z})_{zz'} = (\hat{Z}\vec{\phi})_{zh}(\vec{f}\Sigma_P(\alpha) \vec{f}^T)_{hh'} (\hat{Z}\vec{\phi})^T_{z'h'}$$
#
# $\Sigma_{\hat{c}}$ - covariance in predicted $^{14}$CO from underground spectrum uncertainties
#
# $$L(\vec{\phi}|\vec{c}) = \iiint \frac{e^{-(\vec{c}-\hat{c})^T(\Sigma+\Sigma_{\hat{c}})^{-1}(\vec{c}-\hat{c})/2}}{\sqrt{|2\pi(\Sigma+\Sigma_{\hat{c}})|}} p(\alpha)p(\vec{f})p(\hat{Z})\,d\alpha\, d\vec{f}\, d\hat{Z}$$
#
# $\vec{c}$ - measured $^{14}$CO concentrations
#
# $\Sigma$ - experimental uncertainties

# %% [markdown]
# The next step is to calculate $L(\vec{\phi}_0|\vec{\phi}_0)$ for ~1 million random throws and fit the distribution to get a function for the p-value $p( \leq L|\text{null})$, so we can convert $L$ into standard deviations $\sigma$.
#
# Since experimental error is normally distributed by $\Sigma$, it should be easy to calculate the distribution of $L$ under specific independent variables $\alpha, \vec{f}, \hat{Z}$.  So all we need to randomize over are these variables, and we can then combine their $L$ distributions to get a more accurate (and easier to calculate) conversion to the p-value!

# %% [markdown]
# I think we can incorporate a gaussian uncertainty in $\alpha$ into the unscaled production rate uncertainty, so we'd only need to integrate over $\vec{f}$ and $\hat{Z}$

# %% [markdown]
# More realistically, we should have two gaussian uncertainties on $\alpha$, which we switch between.  Either $\alpha = 0.75 \pm 0.08$ (Literature citations) or $\alpha = 0.093 \pm 0.07$ (Heisinger measurement)

# %% [markdown]
# $$dP_{\text{fast}} = \frac{\partial P}{\partial \vec{\Phi}}\cdot d\vec{\Phi} + \frac{\partial P}{\partial \alpha}d\alpha = N\sigma \sum dE (\frac{E}{190})^\alpha d\vec{\Phi} + N\sigma \sum dE \vec{\Phi} \frac{\partial}{\partial \alpha} (\frac{E}{190})^\alpha = \hat{O}[d\vec{\Phi} + \ln(\frac{\hat{E}}{190}) \vec{\Phi}\, d\alpha]$$
#
# $$\Sigma_P' = dP dP^T = O (d\Phi + \ln(\frac{\hat{E}}{190}) \vec{\Phi}\, d\alpha)(d\Phi + \ln(\frac{\hat{E}}{190}) \vec{\Phi}\, d\alpha)^T O^T = \Sigma_P + O (d\Phi (\ln(\frac{\hat{E}}{190}) \vec{\Phi})^Td\alpha + (\ln(\frac{\hat{E}}{190}) \vec{\Phi})d\Phi^Td\alpha + (\ln(\frac{\hat{E}}{190}) \vec{\Phi})(\ln(\frac{\hat{E}}{190}) \vec{\Phi})^T d\alpha^2) O^T$$

# %%
alphas = np.arange(0.67,1.01,0.01)

# %%
model_names
# Out:
# ['JN-fit_GS-ice_alpha=0.67',
#  'daemonflux_GS-ice_alpha=0.67',
#  "GlobalSplineFitBeta_MCEq_atm-SIBYLL23CPP-('MSIS00', ('SouthPole', 'January'))_GS-ice_alpha=0.67",
#  "HillasGaisser2012 H3a_MCEq_atm-SIBYLL23CPP-('MSIS00', ('SouthPole', 'January'))_GS-ice_alpha=0.67",
#  "HillasGaisser2012 H4a_MCEq_atm-SIBYLL23CPP-('MSIS00', ('SouthPole', 'January'))_GS-ice_alpha=0.67",
#  "PolyGonato_MCEq_atm-SIBYLL23CPP-('MSIS00', ('SouthPole', 'January'))_GS-ice_alpha=0.67",
#  "GaisserStanevTilav 3-gen_MCEq_atm-SIBYLL23CPP-('MSIS00', ('SouthPole', 'January'))_GS-ice_alpha=0.67",
#  "GaisserStanevTilav 4-gen_MCEq_atm-SIBYLL23CPP-('MSIS00', ('SouthPole', 'January'))_GS-ice_alpha=0.67",
#  "CombinedGHandHG H3a_MCEq_atm-SIBYLL23CPP-('MSIS00', ('SouthPole', 'January'))_GS-ice_alpha=0.67",
#  "ZatsepinSokolskaya pamela_MCEq_atm-SIBYLL23CPP-('MSIS00', ('SouthPole', 'January'))_GS-ice_alpha=0.67",
#  "ZatsepinSokolskaya default_MCEq_atm-SIBYLL23CPP-('MSIS00', ('SouthPole', 'January'))_GS-ice_alpha=0.67",
#  "GaisserHonda_MCEq_atm-SIBYLL23CPP-('MSIS00', ('SouthPole', 'January'))_GS-ice_alpha=0.67",
#  "Thunman_MCEq_atm-SIBYLL23CPP-('MSIS00', ('SouthPole', 'January'))_GS-ice_alpha=0.67",
#  "SimplePowerlaw27_MCEq_atm-SIBYLL23CPP-('MSIS00', ('SouthPole', 'January'))_GS-ice_alpha=0.67",
#  "GlobalSplineFitBeta_MCEq_atm-SIBYLL23C03-('MSIS00', ('SouthPole', 'January'))_GS-ice_alpha=0.67",
#  "HillasGaisser2012 H3a_MCEq_atm-SIBYLL23C03-('MSIS00', ('SouthPole', 'January'))_GS-ice_alpha=0.67",
#  "HillasGaisser2012 H4a_MCEq_atm-SIBYLL23C03-('MSIS00', ('SouthPole', 'January'))_GS-ice_alpha=0.67",
#  "PolyGonato_MCEq_atm-SIBYLL23C03-('MSIS00', ('SouthPole', 'January'))_GS-ice_alpha=0.67",
#  "GaisserStanevTilav 3-gen_MCEq_atm-SIBYLL23C03-('MSIS00', ('SouthPole', 'January'))_GS-ice_alpha=0.67",
#  "GaisserStanevTilav 4-gen_MCEq_atm-SIBYLL23C03-('MSIS00', ('SouthPole', 'January'))_GS-ice_alpha=0.67",
#  "CombinedGHandHG H3a_MCEq_atm-SIBYLL23C03-('MSIS00', ('SouthPole', 'January'))_GS-ice_alpha=0.67",
#  "ZatsepinSokolskaya pamela_MCEq_atm-SIBYLL23C03-('MSIS00', ('SouthPole', 'January'))_GS-ice_alpha=0.67",
#  "ZatsepinSokolskaya default_MCEq_atm-SIBYLL23C03-('MSIS00', ('SouthPole', 'January'))_GS-ice_alpha=0.67",
#  "GaisserHonda_MCEq_atm-SIBYLL23C03-('MSIS00', ('SouthPole', 'January'))_GS-ice_alpha=0.67",
#  "Thunman_MCEq_atm-SIBYLL23C03-('MSIS00', ('SouthPole', 'January'))_GS-ice_alpha=0.67",
#  "SimplePowerlaw27_MCEq_atm-SIBYLL23C03-('MSIS00', ('SouthPole', 'January'))_GS-ice_alpha=0.67",
#  "GlobalSplineFitBeta_MCEq_atm-SIBYLL-2.3c-('MSIS00', ('SouthPole', 'January'))_GS-ice_alpha=0.67",
#  "HillasGaisser2012 H3a_MCEq_atm-SIBYLL-2.3c-('MSIS00', ('SouthPole', 'January'))_GS-ice_alpha=0.67",
#  "HillasGaisser2012 H4a_MCEq_atm-SIBYLL-2.3c-('MSIS00', ('SouthPole', 'January'))_GS-ice_alpha=0.67",
#  "PolyGonato_MCEq_atm-SIBYLL-2.3c-('MSIS00', ('SouthPole', 'January'))_GS-ice_alpha=0.67",
#  "GaisserStanevTilav 3-gen_MCEq_atm-SIBYLL-2.3c-('MSIS00', ('SouthPole', 'January'))_GS-ice_alpha=0.67",
#  "GaisserStanevTilav 4-gen_MCEq_atm-SIBYLL-2.3c-('MSIS00', ('SouthPole', 'January'))_GS-ice_alpha=0.67",
#  "CombinedGHandHG H3a_MCEq_atm-SIBYLL-2.3c-('MSIS00', ('SouthPole', 'January'))_GS-ice_alpha=0.67",
#  "ZatsepinSokolskaya pamela_MCEq_atm-SIBYLL-2.3c-('MSIS00', ('SouthPole', 'January'))_GS-ice_alpha=0.67",
#  "ZatsepinSokolskaya default_MCEq_atm-SIBYLL-2.3c-('MSIS00', ('SouthPole', 'January'))_GS-ice_alpha=0.67",
#  "GaisserHonda_MCEq_atm-SIBYLL-2.3c-('MSIS00', ('SouthPole', 'January'))_GS-ice_alpha=0.67",
#  "Thunman_MCEq_atm-SIBYLL-2.3c-('MSIS00', ('SouthPole', 'January'))_GS-ice_alpha=0.67",
#  "SimplePowerlaw27_MCEq_atm-SIBYLL-2.3c-('MSIS00', ('SouthPole', 'January'))_GS-ice_alpha=0.67",
#  "GlobalSplineFitBeta_MCEq_atm-SIBYLL-2.3-('MSIS00', ('SouthPole', 'January'))_GS-ice_alpha=0.67",
#  "HillasGaisser2012 H3a_MCEq_atm-SIBYLL-2.3-('MSIS00', ('SouthPole', 'January'))_GS-ice_alpha=0.67",
#  "HillasGaisser2012 H4a_MCEq_atm-SIBYLL-2.3-('MSIS00', ('SouthPole', 'January'))_GS-ice_alpha=0.67",
#  "PolyGonato_MCEq_atm-SIBYLL-2.3-('MSIS00', ('SouthPole', 'January'))_GS-ice_alpha=0.67",
#  "GaisserStanevTilav 3-gen_MCEq_atm-SIBYLL-2.3-('MSIS00', ('SouthPole', 'January'))_GS-ice_alpha=0.67",
#  "GaisserStanevTilav 4-gen_MCEq_atm-SIBYLL-2.3-('MSIS00', ('SouthPole', 'January'))_GS-ice_alpha=0.67",
#  "CombinedGHandHG H3a_MCEq_atm-SIBYLL-2.3-('MSIS00', ('SouthPole', 'January'))_GS-ice_alpha=0.67",
#  "ZatsepinSokolskaya pamela_MCEq_atm-SIBYLL-2.3-('MSIS00', ('SouthPole', 'January'))_GS-ice_alpha=0.67",
#  "ZatsepinSokolskaya default_MCEq_atm-SIBYLL-2.3-('MSIS00', ('SouthPole', 'January'))_GS-ice_alpha=0.67",
#  "GaisserHonda_MCEq_atm-SIBYLL-2.3-('MSIS00', ('SouthPole', 'January'))_GS-ice_alpha=0.67",
#  "Thunman_MCEq_atm-SIBYLL-2.3-('MSIS00', ('SouthPole', 'January'))_GS-ice_alpha=0.67",
#  "SimplePowerlaw27_MCEq_atm-SIBYLL-2.3-('MSIS00', ('SouthPole', 'January'))_GS-ice_alpha=0.67",
#  "GlobalSplineFitBeta_MCEq_atm-SIBYLL-2.1-('MSIS00', ('SouthPole', 'January'))_GS-ice_alpha=0.67",
#  "HillasGaisser2012 H3a_MCEq_atm-SIBYLL-2.1-('MSIS00', ('SouthPole', 'January'))_GS-ice_alpha=0.67",
#  "HillasGaisser2012 H4a_MCEq_atm-SIBYLL-2.1-('MSIS00', ('SouthPole', 'January'))_GS-ice_alpha=0.67",
#  "PolyGonato_MCEq_atm-SIBYLL-2.1-('MSIS00', ('SouthPole', 'January'))_GS-ice_alpha=0.67",
#  "GaisserStanevTilav 3-gen_MCEq_atm-SIBYLL-2.1-('MSIS00', ('SouthPole', 'January'))_GS-ice_alpha=0.67",
#  "GaisserStanevTilav 4-gen_MCEq_atm-SIBYLL-2.1-('MSIS00', ('SouthPole', 'January'))_GS-ice_alpha=0.67",
#  "CombinedGHandHG H3a_MCEq_atm-SIBYLL-2.1-('MSIS00', ('SouthPole', 'January'))_GS-ice_alpha=0.67",
#  "ZatsepinSokolskaya pamela_MCEq_atm-SIBYLL-2.1-('MSIS00', ('SouthPole', 'January'))_GS-ice_alpha=0.67",
#  "ZatsepinSokolskaya default_MCEq_atm-SIBYLL-2.1-('MSIS00', ('SouthPole', 'January'))_GS-ice_alpha=0.67",
#  "GaisserHonda_MCEq_atm-SIBYLL-2.1-('MSIS00', ('SouthPole', 'January'))_GS-ice_alpha=0.67",
#  "Thunman_MCEq_atm-SIBYLL-2.1-('MSIS00', ('SouthPole', 'January'))_GS-ice_alpha=0.67",
#  "SimplePowerlaw27_MCEq_atm-SIBYLL-2.1-('MSIS00', ('SouthPole', 'January'))_GS-ice_alpha=0.67",
#  "GlobalSplineFitBeta_MCEq_atm-EPOS-LHC-('MSIS00', ('SouthPole', 'January'))_GS-ice_alpha=0.67",
#  "HillasGaisser2012 H3a_MCEq_atm-EPOS-LHC-('MSIS00', ('SouthPole', 'January'))_GS-ice_alpha=0.67",
#  "HillasGaisser2012 H4a_MCEq_atm-EPOS-LHC-('MSIS00', ('SouthPole', 'January'))_GS-ice_alpha=0.67",
#  "PolyGonato_MCEq_atm-EPOS-LHC-('MSIS00', ('SouthPole', 'January'))_GS-ice_alpha=0.67",
#  "GaisserStanevTilav 3-gen_MCEq_atm-EPOS-LHC-('MSIS00', ('SouthPole', 'January'))_GS-ice_alpha=0.67",
#  "GaisserStanevTilav 4-gen_MCEq_atm-EPOS-LHC-('MSIS00', ('SouthPole', 'January'))_GS-ice_alpha=0.67",
#  "CombinedGHandHG H3a_MCEq_atm-EPOS-LHC-('MSIS00', ('SouthPole', 'January'))_GS-ice_alpha=0.67",
#  "ZatsepinSokolskaya pamela_MCEq_atm-EPOS-LHC-('MSIS00', ('SouthPole', 'January'))_GS-ice_alpha=0.67",
#  "ZatsepinSokolskaya default_MCEq_atm-EPOS-LHC-('MSIS00', ('SouthPole', 'January'))_GS-ice_alpha=0.67",
#  "GaisserHonda_MCEq_atm-EPOS-LHC-('MSIS00', ('SouthPole', 'January'))_GS-ice_alpha=0.67",
#  "Thunman_MCEq_atm-EPOS-LHC-('MSIS00', ('SouthPole', 'January'))_GS-ice_alpha=0.67",
#  "SimplePowerlaw27_MCEq_atm-EPOS-LHC-('MSIS00', ('SouthPole', 'January'))_GS-ice_alpha=0.67",
#  "GlobalSplineFitBeta_MCEq_atm-QGSJET-II-04-('MSIS00', ('SouthPole', 'January'))_GS-ice_alpha=0.67",
#  "HillasGaisser2012 H3a_MCEq_atm-QGSJET-II-04-('MSIS00', ('SouthPole', 'January'))_GS-ice_alpha=0.67",
#  "HillasGaisser2012 H4a_MCEq_atm-QGSJET-II-04-('MSIS00', ('SouthPole', 'January'))_GS-ice_alpha=0.67",
#  "PolyGonato_MCEq_atm-QGSJET-II-04-('MSIS00', ('SouthPole', 'January'))_GS-ice_alpha=0.67",
#  "GaisserStanevTilav 3-gen_MCEq_atm-QGSJET-II-04-('MSIS00', ('SouthPole', 'January'))_GS-ice_alpha=0.67",
#  "GaisserStanevTilav 4-gen_MCEq_atm-QGSJET-II-04-('MSIS00', ('SouthPole', 'January'))_GS-ice_alpha=0.67",
#  "CombinedGHandHG H3a_MCEq_atm-QGSJET-II-04-('MSIS00', ('SouthPole', 'January'))_GS-ice_alpha=0.67",
#  "ZatsepinSokolskaya pamela_MCEq_atm-QGSJET-II-04-('MSIS00', ('SouthPole', 'January'))_GS-ice_alpha=0.67",
#  "ZatsepinSokolskaya default_MCEq_atm-QGSJET-II-04-('MSIS00', ('SouthPole', 'January'))_GS-ice_alpha=0.67",
#  "GaisserHonda_MCEq_atm-QGSJET-II-04-('MSIS00', ('SouthPole', 'January'))_GS-ice_alpha=0.67",
#  "Thunman_MCEq_atm-QGSJET-II-04-('MSIS00', ('SouthPole', 'January'))_GS-ice_alpha=0.67",
#  "SimplePowerlaw27_MCEq_atm-QGSJET-II-04-('MSIS00', ('SouthPole', 'January'))_GS-ice_alpha=0.67",
#  "GlobalSplineFitBeta_MCEq_atm-QGSJETII03-('MSIS00', ('SouthPole', 'January'))_GS-ice_alpha=0.67",
#  "HillasGaisser2012 H3a_MCEq_atm-QGSJETII03-('MSIS00', ('SouthPole', 'January'))_GS-ice_alpha=0.67",
#  "HillasGaisser2012 H4a_MCEq_atm-QGSJETII03-('MSIS00', ('SouthPole', 'January'))_GS-ice_alpha=0.67",
#  "PolyGonato_MCEq_atm-QGSJETII03-('MSIS00', ('SouthPole', 'January'))_GS-ice_alpha=0.67",
#  "GaisserStanevTilav 3-gen_MCEq_atm-QGSJETII03-('MSIS00', ('SouthPole', 'January'))_GS-ice_alpha=0.67",
#  "GaisserStanevTilav 4-gen_MCEq_atm-QGSJETII03-('MSIS00', ('SouthPole', 'January'))_GS-ice_alpha=0.67",
#  "CombinedGHandHG H3a_MCEq_atm-QGSJETII03-('MSIS00', ('SouthPole', 'January'))_GS-ice_alpha=0.67",
#  "ZatsepinSokolskaya pamela_MCEq_atm-QGSJETII03-('MSIS00', ('SouthPole', 'January'))_GS-ice_alpha=0.67",
#  "ZatsepinSokolskaya default_MCEq_atm-QGSJETII03-('MSIS00', ('SouthPole', 'January'))_GS-ice_alpha=0.67",
#  "GaisserHonda_MCEq_atm-QGSJETII03-('MSIS00', ('SouthPole', 'January'))_GS-ice_alpha=0.67",
#  "Thunman_MCEq_atm-QGSJETII03-('MSIS00', ('SouthPole', 'January'))_GS-ice_alpha=0.67",
#  "SimplePowerlaw27_MCEq_atm-QGSJETII03-('MSIS00', ('SouthPole', 'January'))_GS-ice_alpha=0.67",
#  "GlobalSplineFitBeta_MCEq_atm-QGSJET01C-('MSIS00', ('SouthPole', 'January'))_GS-ice_alpha=0.67",
#  "HillasGaisser2012 H3a_MCEq_atm-QGSJET01C-('MSIS00', ('SouthPole', 'January'))_GS-ice_alpha=0.67",
#  "HillasGaisser2012 H4a_MCEq_atm-QGSJET01C-('MSIS00', ('SouthPole', 'January'))_GS-ice_alpha=0.67",
#  "PolyGonato_MCEq_atm-QGSJET01C-('MSIS00', ('SouthPole', 'January'))_GS-ice_alpha=0.67",
#  "GaisserStanevTilav 3-gen_MCEq_atm-QGSJET01C-('MSIS00', ('SouthPole', 'January'))_GS-ice_alpha=0.67",
#  "GaisserStanevTilav 4-gen_MCEq_atm-QGSJET01C-('MSIS00', ('SouthPole', 'January'))_GS-ice_alpha=0.67",
#  "CombinedGHandHG H3a_MCEq_atm-QGSJET01C-('MSIS00', ('SouthPole', 'January'))_GS-ice_alpha=0.67",
#  "ZatsepinSokolskaya pamela_MCEq_atm-QGSJET01C-('MSIS00', ('SouthPole', 'January'))_GS-ice_alpha=0.67",
#  "ZatsepinSokolskaya default_MCEq_atm-QGSJET01C-('MSIS00', ('SouthPole', 'January'))_GS-ice_alpha=0.67",
#  "GaisserHonda_MCEq_atm-QGSJET01C-('MSIS00', ('SouthPole', 'January'))_GS-ice_alpha=0.67",
#  "Thunman_MCEq_atm-QGSJET01C-('MSIS00', ('SouthPole', 'January'))_GS-ice_alpha=0.67",
#  "SimplePowerlaw27_MCEq_atm-QGSJET01C-('MSIS00', ('SouthPole', 'January'))_GS-ice_alpha=0.67",
#  "GlobalSplineFitBeta_MCEq_atm-DPMJETIII306-('MSIS00', ('SouthPole', 'January'))_GS-ice_alpha=0.67",
#  "HillasGaisser2012 H3a_MCEq_atm-DPMJETIII306-('MSIS00', ('SouthPole', 'January'))_GS-ice_alpha=0.67",
#  "HillasGaisser2012 H4a_MCEq_atm-DPMJETIII306-('MSIS00', ('SouthPole', 'January'))_GS-ice_alpha=0.67",
#  "PolyGonato_MCEq_atm-DPMJETIII306-('MSIS00', ('SouthPole', 'January'))_GS-ice_alpha=0.67",
#  "GaisserStanevTilav 3-gen_MCEq_atm-DPMJETIII306-('MSIS00', ('SouthPole', 'January'))_GS-ice_alpha=0.67",
#  "GaisserStanevTilav 4-gen_MCEq_atm-DPMJETIII306-('MSIS00', ('SouthPole', 'January'))_GS-ice_alpha=0.67",
#  "CombinedGHandHG H3a_MCEq_atm-DPMJETIII306-('MSIS00', ('SouthPole', 'January'))_GS-ice_alpha=0.67",
#  "ZatsepinSokolskaya pamela_MCEq_atm-DPMJETIII306-('MSIS00', ('SouthPole', 'January'))_GS-ice_alpha=0.67",
#  "ZatsepinSokolskaya default_MCEq_atm-DPMJETIII306-('MSIS00', ('SouthPole', 'January'))_GS-ice_alpha=0.67",
#  "GaisserHonda_MCEq_atm-DPMJETIII306-('MSIS00', ('SouthPole', 'January'))_GS-ice_alpha=0.67",
#  "Thunman_MCEq_atm-DPMJETIII306-('MSIS00', ('SouthPole', 'January'))_GS-ice_alpha=0.67",
#  "SimplePowerlaw27_MCEq_atm-DPMJETIII306-('MSIS00', ('SouthPole', 'January'))_GS-ice_alpha=0.67",
#  "GlobalSplineFitBeta_MCEq_atm-DPMJETIII191-('MSIS00', ('SouthPole', 'January'))_GS-ice_alpha=0.67",
#  "HillasGaisser2012 H3a_MCEq_atm-DPMJETIII191-('MSIS00', ('SouthPole', 'January'))_GS-ice_alpha=0.67",
#  "HillasGaisser2012 H4a_MCEq_atm-DPMJETIII191-('MSIS00', ('SouthPole', 'January'))_GS-ice_alpha=0.67",
#  "PolyGonato_MCEq_atm-DPMJETIII191-('MSIS00', ('SouthPole', 'January'))_GS-ice_alpha=0.67",
#  "GaisserStanevTilav 3-gen_MCEq_atm-DPMJETIII191-('MSIS00', ('SouthPole', 'January'))_GS-ice_alpha=0.67",
#  "GaisserStanevTilav 4-gen_MCEq_atm-DPMJETIII191-('MSIS00', ('SouthPole', 'January'))_GS-ice_alpha=0.67",
#  "CombinedGHandHG H3a_MCEq_atm-DPMJETIII191-('MSIS00', ('SouthPole', 'January'))_GS-ice_alpha=0.67",
#  "ZatsepinSokolskaya pamela_MCEq_atm-DPMJETIII191-('MSIS00', ('SouthPole', 'January'))_GS-ice_alpha=0.67",
#  "ZatsepinSokolskaya default_MCEq_atm-DPMJETIII191-('MSIS00', ('SouthPole', 'January'))_GS-ice_alpha=0.67",
#  "GaisserHonda_MCEq_atm-DPMJETIII191-('MSIS00', ('SouthPole', 'January'))_GS-ice_alpha=0.67",
#  "Thunman_MCEq_atm-DPMJETIII191-('MSIS00', ('SouthPole', 'January'))_GS-ice_alpha=0.67",
#  "SimplePowerlaw27_MCEq_atm-DPMJETIII191-('MSIS00', ('SouthPole', 'January'))_GS-ice_alpha=0.67",
#  "GlobalSplineFitBeta_MCEq_atm-SIBYLL23CPP-('MSIS00', ('SouthPole', 'July'))_GS-ice_alpha=0.67",
#  "HillasGaisser2012 H3a_MCEq_atm-SIBYLL23CPP-('MSIS00', ('SouthPole', 'July'))_GS-ice_alpha=0.67",
#  "HillasGaisser2012 H4a_MCEq_atm-SIBYLL23CPP-('MSIS00', ('SouthPole', 'July'))_GS-ice_alpha=0.67",
#  "PolyGonato_MCEq_atm-SIBYLL23CPP-('MSIS00', ('SouthPole', 'July'))_GS-ice_alpha=0.67",
#  "GaisserStanevTilav 3-gen_MCEq_atm-SIBYLL23CPP-('MSIS00', ('SouthPole', 'July'))_GS-ice_alpha=0.67",
#  "GaisserStanevTilav 4-gen_MCEq_atm-SIBYLL23CPP-('MSIS00', ('SouthPole', 'July'))_GS-ice_alpha=0.67",
#  "CombinedGHandHG H3a_MCEq_atm-SIBYLL23CPP-('MSIS00', ('SouthPole', 'July'))_GS-ice_alpha=0.67",
#  "ZatsepinSokolskaya pamela_MCEq_atm-SIBYLL23CPP-('MSIS00', ('SouthPole', 'July'))_GS-ice_alpha=0.67",
#  "ZatsepinSokolskaya default_MCEq_atm-SIBYLL23CPP-('MSIS00', ('SouthPole', 'July'))_GS-ice_alpha=0.67",
#  "GaisserHonda_MCEq_atm-SIBYLL23CPP-('MSIS00', ('SouthPole', 'July'))_GS-ice_alpha=0.67",
#  "Thunman_MCEq_atm-SIBYLL23CPP-('MSIS00', ('SouthPole', 'July'))_GS-ice_alpha=0.67",
#  "SimplePowerlaw27_MCEq_atm-SIBYLL23CPP-('MSIS00', ('SouthPole', 'July'))_GS-ice_alpha=0.67",
#  "GlobalSplineFitBeta_MCEq_atm-SIBYLL23C03-('MSIS00', ('SouthPole', 'July'))_GS-ice_alpha=0.67",
#  "HillasGaisser2012 H3a_MCEq_atm-SIBYLL23C03-('MSIS00', ('SouthPole', 'July'))_GS-ice_alpha=0.67",
#  "HillasGaisser2012 H4a_MCEq_atm-SIBYLL23C03-('MSIS00', ('SouthPole', 'July'))_GS-ice_alpha=0.67",
#  "PolyGonato_MCEq_atm-SIBYLL23C03-('MSIS00', ('SouthPole', 'July'))_GS-ice_alpha=0.67",
#  "GaisserStanevTilav 3-gen_MCEq_atm-SIBYLL23C03-('MSIS00', ('SouthPole', 'July'))_GS-ice_alpha=0.67",
#  "GaisserStanevTilav 4-gen_MCEq_atm-SIBYLL23C03-('MSIS00', ('SouthPole', 'July'))_GS-ice_alpha=0.67",
#  "CombinedGHandHG H3a_MCEq_atm-SIBYLL23C03-('MSIS00', ('SouthPole', 'July'))_GS-ice_alpha=0.67",
#  "ZatsepinSokolskaya pamela_MCEq_atm-SIBYLL23C03-('MSIS00', ('SouthPole', 'July'))_GS-ice_alpha=0.67",
#  "ZatsepinSokolskaya default_MCEq_atm-SIBYLL23C03-('MSIS00', ('SouthPole', 'July'))_GS-ice_alpha=0.67",
#  "GaisserHonda_MCEq_atm-SIBYLL23C03-('MSIS00', ('SouthPole', 'July'))_GS-ice_alpha=0.67",
#  "Thunman_MCEq_atm-SIBYLL23C03-('MSIS00', ('SouthPole', 'July'))_GS-ice_alpha=0.67",
#  "SimplePowerlaw27_MCEq_atm-SIBYLL23C03-('MSIS00', ('SouthPole', 'July'))_GS-ice_alpha=0.67",
#  "GlobalSplineFitBeta_MCEq_atm-SIBYLL-2.3c-('MSIS00', ('SouthPole', 'July'))_GS-ice_alpha=0.67",
#  "HillasGaisser2012 H3a_MCEq_atm-SIBYLL-2.3c-('MSIS00', ('SouthPole', 'July'))_GS-ice_alpha=0.67",
#  "HillasGaisser2012 H4a_MCEq_atm-SIBYLL-2.3c-('MSIS00', ('SouthPole', 'July'))_GS-ice_alpha=0.67",
#  "PolyGonato_MCEq_atm-SIBYLL-2.3c-('MSIS00', ('SouthPole', 'July'))_GS-ice_alpha=0.67",
#  "GaisserStanevTilav 3-gen_MCEq_atm-SIBYLL-2.3c-('MSIS00', ('SouthPole', 'July'))_GS-ice_alpha=0.67",
#  "GaisserStanevTilav 4-gen_MCEq_atm-SIBYLL-2.3c-('MSIS00', ('SouthPole', 'July'))_GS-ice_alpha=0.67",
#  "CombinedGHandHG H3a_MCEq_atm-SIBYLL-2.3c-('MSIS00', ('SouthPole', 'July'))_GS-ice_alpha=0.67",
#  "ZatsepinSokolskaya pamela_MCEq_atm-SIBYLL-2.3c-('MSIS00', ('SouthPole', 'July'))_GS-ice_alpha=0.67",
#  "ZatsepinSokolskaya default_MCEq_atm-SIBYLL-2.3c-('MSIS00', ('SouthPole', 'July'))_GS-ice_alpha=0.67",
#  "GaisserHonda_MCEq_atm-SIBYLL-2.3c-('MSIS00', ('SouthPole', 'July'))_GS-ice_alpha=0.67",
#  "Thunman_MCEq_atm-SIBYLL-2.3c-('MSIS00', ('SouthPole', 'July'))_GS-ice_alpha=0.67",
#  "SimplePowerlaw27_MCEq_atm-SIBYLL-2.3c-('MSIS00', ('SouthPole', 'July'))_GS-ice_alpha=0.67",
#  "GlobalSplineFitBeta_MCEq_atm-SIBYLL-2.3-('MSIS00', ('SouthPole', 'July'))_GS-ice_alpha=0.67",
#  "HillasGaisser2012 H3a_MCEq_atm-SIBYLL-2.3-('MSIS00', ('SouthPole', 'July'))_GS-ice_alpha=0.67",
#  "HillasGaisser2012 H4a_MCEq_atm-SIBYLL-2.3-('MSIS00', ('SouthPole', 'July'))_GS-ice_alpha=0.67",
#  "PolyGonato_MCEq_atm-SIBYLL-2.3-('MSIS00', ('SouthPole', 'July'))_GS-ice_alpha=0.67",
#  "GaisserStanevTilav 3-gen_MCEq_atm-SIBYLL-2.3-('MSIS00', ('SouthPole', 'July'))_GS-ice_alpha=0.67",
#  "GaisserStanevTilav 4-gen_MCEq_atm-SIBYLL-2.3-('MSIS00', ('SouthPole', 'July'))_GS-ice_alpha=0.67",
#  "CombinedGHandHG H3a_MCEq_atm-SIBYLL-2.3-('MSIS00', ('SouthPole', 'July'))_GS-ice_alpha=0.67",
#  "ZatsepinSokolskaya pamela_MCEq_atm-SIBYLL-2.3-('MSIS00', ('SouthPole', 'July'))_GS-ice_alpha=0.67",
#  "ZatsepinSokolskaya default_MCEq_atm-SIBYLL-2.3-('MSIS00', ('SouthPole', 'July'))_GS-ice_alpha=0.67",
#  "GaisserHonda_MCEq_atm-SIBYLL-2.3-('MSIS00', ('SouthPole', 'July'))_GS-ice_alpha=0.67",
#  "Thunman_MCEq_atm-SIBYLL-2.3-('MSIS00', ('SouthPole', 'July'))_GS-ice_alpha=0.67",
#  "SimplePowerlaw27_MCEq_atm-SIBYLL-2.3-('MSIS00', ('SouthPole', 'July'))_GS-ice_alpha=0.67",
#  "GlobalSplineFitBeta_MCEq_atm-SIBYLL-2.1-('MSIS00', ('SouthPole', 'July'))_GS-ice_alpha=0.67",
#  "HillasGaisser2012 H3a_MCEq_atm-SIBYLL-2.1-('MSIS00', ('SouthPole', 'July'))_GS-ice_alpha=0.67",
#  "HillasGaisser2012 H4a_MCEq_atm-SIBYLL-2.1-('MSIS00', ('SouthPole', 'July'))_GS-ice_alpha=0.67",
#  "PolyGonato_MCEq_atm-SIBYLL-2.1-('MSIS00', ('SouthPole', 'July'))_GS-ice_alpha=0.67",
#  "GaisserStanevTilav 3-gen_MCEq_atm-SIBYLL-2.1-('MSIS00', ('SouthPole', 'July'))_GS-ice_alpha=0.67",
#  "GaisserStanevTilav 4-gen_MCEq_atm-SIBYLL-2.1-('MSIS00', ('SouthPole', 'July'))_GS-ice_alpha=0.67",
#  "CombinedGHandHG H3a_MCEq_atm-SIBYLL-2.1-('MSIS00', ('SouthPole', 'July'))_GS-ice_alpha=0.67",
#  "ZatsepinSokolskaya pamela_MCEq_atm-SIBYLL-2.1-('MSIS00', ('SouthPole', 'July'))_GS-ice_alpha=0.67",
#  "ZatsepinSokolskaya default_MCEq_atm-SIBYLL-2.1-('MSIS00', ('SouthPole', 'July'))_GS-ice_alpha=0.67",
#  "GaisserHonda_MCEq_atm-SIBYLL-2.1-('MSIS00', ('SouthPole', 'July'))_GS-ice_alpha=0.67",
#  "Thunman_MCEq_atm-SIBYLL-2.1-('MSIS00', ('SouthPole', 'July'))_GS-ice_alpha=0.67",
#  "SimplePowerlaw27_MCEq_atm-SIBYLL-2.1-('MSIS00', ('SouthPole', 'July'))_GS-ice_alpha=0.67",
#  "GlobalSplineFitBeta_MCEq_atm-EPOS-LHC-('MSIS00', ('SouthPole', 'July'))_GS-ice_alpha=0.67",
#  "HillasGaisser2012 H3a_MCEq_atm-EPOS-LHC-('MSIS00', ('SouthPole', 'July'))_GS-ice_alpha=0.67",
#  "HillasGaisser2012 H4a_MCEq_atm-EPOS-LHC-('MSIS00', ('SouthPole', 'July'))_GS-ice_alpha=0.67",
#  "PolyGonato_MCEq_atm-EPOS-LHC-('MSIS00', ('SouthPole', 'July'))_GS-ice_alpha=0.67",
#  "GaisserStanevTilav 3-gen_MCEq_atm-EPOS-LHC-('MSIS00', ('SouthPole', 'July'))_GS-ice_alpha=0.67",
#  "GaisserStanevTilav 4-gen_MCEq_atm-EPOS-LHC-('MSIS00', ('SouthPole', 'July'))_GS-ice_alpha=0.67",
#  "CombinedGHandHG H3a_MCEq_atm-EPOS-LHC-('MSIS00', ('SouthPole', 'July'))_GS-ice_alpha=0.67",
#  "ZatsepinSokolskaya pamela_MCEq_atm-EPOS-LHC-('MSIS00', ('SouthPole', 'July'))_GS-ice_alpha=0.67",
#  "ZatsepinSokolskaya default_MCEq_atm-EPOS-LHC-('MSIS00', ('SouthPole', 'July'))_GS-ice_alpha=0.67",
#  "GaisserHonda_MCEq_atm-EPOS-LHC-('MSIS00', ('SouthPole', 'July'))_GS-ice_alpha=0.67",
#  "Thunman_MCEq_atm-EPOS-LHC-('MSIS00', ('SouthPole', 'July'))_GS-ice_alpha=0.67",
#  "SimplePowerlaw27_MCEq_atm-EPOS-LHC-('MSIS00', ('SouthPole', 'July'))_GS-ice_alpha=0.67",
#  "GlobalSplineFitBeta_MCEq_atm-QGSJET-II-04-('MSIS00', ('SouthPole', 'July'))_GS-ice_alpha=0.67",
#  "HillasGaisser2012 H3a_MCEq_atm-QGSJET-II-04-('MSIS00', ('SouthPole', 'July'))_GS-ice_alpha=0.67",
#  "HillasGaisser2012 H4a_MCEq_atm-QGSJET-II-04-('MSIS00', ('SouthPole', 'July'))_GS-ice_alpha=0.67",
#  "PolyGonato_MCEq_atm-QGSJET-II-04-('MSIS00', ('SouthPole', 'July'))_GS-ice_alpha=0.67",
#  "GaisserStanevTilav 3-gen_MCEq_atm-QGSJET-II-04-('MSIS00', ('SouthPole', 'July'))_GS-ice_alpha=0.67",
#  "GaisserStanevTilav 4-gen_MCEq_atm-QGSJET-II-04-('MSIS00', ('SouthPole', 'July'))_GS-ice_alpha=0.67",
#  "CombinedGHandHG H3a_MCEq_atm-QGSJET-II-04-('MSIS00', ('SouthPole', 'July'))_GS-ice_alpha=0.67",
#  "ZatsepinSokolskaya pamela_MCEq_atm-QGSJET-II-04-('MSIS00', ('SouthPole', 'July'))_GS-ice_alpha=0.67",
#  "ZatsepinSokolskaya default_MCEq_atm-QGSJET-II-04-('MSIS00', ('SouthPole', 'July'))_GS-ice_alpha=0.67",
#  "GaisserHonda_MCEq_atm-QGSJET-II-04-('MSIS00', ('SouthPole', 'July'))_GS-ice_alpha=0.67",
#  "Thunman_MCEq_atm-QGSJET-II-04-('MSIS00', ('SouthPole', 'July'))_GS-ice_alpha=0.67",
#  "SimplePowerlaw27_MCEq_atm-QGSJET-II-04-('MSIS00', ('SouthPole', 'July'))_GS-ice_alpha=0.67",
#  "GlobalSplineFitBeta_MCEq_atm-QGSJETII03-('MSIS00', ('SouthPole', 'July'))_GS-ice_alpha=0.67",
#  "HillasGaisser2012 H3a_MCEq_atm-QGSJETII03-('MSIS00', ('SouthPole', 'July'))_GS-ice_alpha=0.67",
#  "HillasGaisser2012 H4a_MCEq_atm-QGSJETII03-('MSIS00', ('SouthPole', 'July'))_GS-ice_alpha=0.67",
#  "PolyGonato_MCEq_atm-QGSJETII03-('MSIS00', ('SouthPole', 'July'))_GS-ice_alpha=0.67",
#  "GaisserStanevTilav 3-gen_MCEq_atm-QGSJETII03-('MSIS00', ('SouthPole', 'July'))_GS-ice_alpha=0.67",
#  "GaisserStanevTilav 4-gen_MCEq_atm-QGSJETII03-('MSIS00', ('SouthPole', 'July'))_GS-ice_alpha=0.67",
#  "CombinedGHandHG H3a_MCEq_atm-QGSJETII03-('MSIS00', ('SouthPole', 'July'))_GS-ice_alpha=0.67",
#  "ZatsepinSokolskaya pamela_MCEq_atm-QGSJETII03-('MSIS00', ('SouthPole', 'July'))_GS-ice_alpha=0.67",
#  "ZatsepinSokolskaya default_MCEq_atm-QGSJETII03-('MSIS00', ('SouthPole', 'July'))_GS-ice_alpha=0.67",
#  "GaisserHonda_MCEq_atm-QGSJETII03-('MSIS00', ('SouthPole', 'July'))_GS-ice_alpha=0.67",
#  "Thunman_MCEq_atm-QGSJETII03-('MSIS00', ('SouthPole', 'July'))_GS-ice_alpha=0.67",
#  "SimplePowerlaw27_MCEq_atm-QGSJETII03-('MSIS00', ('SouthPole', 'July'))_GS-ice_alpha=0.67",
#  "GlobalSplineFitBeta_MCEq_atm-QGSJET01C-('MSIS00', ('SouthPole', 'July'))_GS-ice_alpha=0.67",
#  "HillasGaisser2012 H3a_MCEq_atm-QGSJET01C-('MSIS00', ('SouthPole', 'July'))_GS-ice_alpha=0.67",
#  "HillasGaisser2012 H4a_MCEq_atm-QGSJET01C-('MSIS00', ('SouthPole', 'July'))_GS-ice_alpha=0.67",
#  "PolyGonato_MCEq_atm-QGSJET01C-('MSIS00', ('SouthPole', 'July'))_GS-ice_alpha=0.67",
#  "GaisserStanevTilav 3-gen_MCEq_atm-QGSJET01C-('MSIS00', ('SouthPole', 'July'))_GS-ice_alpha=0.67",
#  "GaisserStanevTilav 4-gen_MCEq_atm-QGSJET01C-('MSIS00', ('SouthPole', 'July'))_GS-ice_alpha=0.67",
#  "CombinedGHandHG H3a_MCEq_atm-QGSJET01C-('MSIS00', ('SouthPole', 'July'))_GS-ice_alpha=0.67",
#  "ZatsepinSokolskaya pamela_MCEq_atm-QGSJET01C-('MSIS00', ('SouthPole', 'July'))_GS-ice_alpha=0.67",
#  "ZatsepinSokolskaya default_MCEq_atm-QGSJET01C-('MSIS00', ('SouthPole', 'July'))_GS-ice_alpha=0.67",
#  "GaisserHonda_MCEq_atm-QGSJET01C-('MSIS00', ('SouthPole', 'July'))_GS-ice_alpha=0.67",
#  "Thunman_MCEq_atm-QGSJET01C-('MSIS00', ('SouthPole', 'July'))_GS-ice_alpha=0.67",
#  "SimplePowerlaw27_MCEq_atm-QGSJET01C-('MSIS00', ('SouthPole', 'July'))_GS-ice_alpha=0.67",
#  "GlobalSplineFitBeta_MCEq_atm-DPMJETIII306-('MSIS00', ('SouthPole', 'July'))_GS-ice_alpha=0.67",
#  "HillasGaisser2012 H3a_MCEq_atm-DPMJETIII306-('MSIS00', ('SouthPole', 'July'))_GS-ice_alpha=0.67",
#  "HillasGaisser2012 H4a_MCEq_atm-DPMJETIII306-('MSIS00', ('SouthPole', 'July'))_GS-ice_alpha=0.67",
#  "PolyGonato_MCEq_atm-DPMJETIII306-('MSIS00', ('SouthPole', 'July'))_GS-ice_alpha=0.67",
#  "GaisserStanevTilav 3-gen_MCEq_atm-DPMJETIII306-('MSIS00', ('SouthPole', 'July'))_GS-ice_alpha=0.67",
#  "GaisserStanevTilav 4-gen_MCEq_atm-DPMJETIII306-('MSIS00', ('SouthPole', 'July'))_GS-ice_alpha=0.67",
#  "CombinedGHandHG H3a_MCEq_atm-DPMJETIII306-('MSIS00', ('SouthPole', 'July'))_GS-ice_alpha=0.67",
#  "ZatsepinSokolskaya pamela_MCEq_atm-DPMJETIII306-('MSIS00', ('SouthPole', 'July'))_GS-ice_alpha=0.67",
#  "ZatsepinSokolskaya default_MCEq_atm-DPMJETIII306-('MSIS00', ('SouthPole', 'July'))_GS-ice_alpha=0.67",
#  "GaisserHonda_MCEq_atm-DPMJETIII306-('MSIS00', ('SouthPole', 'July'))_GS-ice_alpha=0.67",
#  "Thunman_MCEq_atm-DPMJETIII306-('MSIS00', ('SouthPole', 'July'))_GS-ice_alpha=0.67",
#  "SimplePowerlaw27_MCEq_atm-DPMJETIII306-('MSIS00', ('SouthPole', 'July'))_GS-ice_alpha=0.67",
#  "GlobalSplineFitBeta_MCEq_atm-DPMJETIII191-('MSIS00', ('SouthPole', 'July'))_GS-ice_alpha=0.67",
#  "HillasGaisser2012 H3a_MCEq_atm-DPMJETIII191-('MSIS00', ('SouthPole', 'July'))_GS-ice_alpha=0.67",
#  "HillasGaisser2012 H4a_MCEq_atm-DPMJETIII191-('MSIS00', ('SouthPole', 'July'))_GS-ice_alpha=0.67",
#  "PolyGonato_MCEq_atm-DPMJETIII191-('MSIS00', ('SouthPole', 'July'))_GS-ice_alpha=0.67",
#  "GaisserStanevTilav 3-gen_MCEq_atm-DPMJETIII191-('MSIS00', ('SouthPole', 'July'))_GS-ice_alpha=0.67",
#  "GaisserStanevTilav 4-gen_MCEq_atm-DPMJETIII191-('MSIS00', ('SouthPole', 'July'))_GS-ice_alpha=0.67",
#  "CombinedGHandHG H3a_MCEq_atm-DPMJETIII191-('MSIS00', ('SouthPole', 'July'))_GS-ice_alpha=0.67",
#  "ZatsepinSokolskaya pamela_MCEq_atm-DPMJETIII191-('MSIS00', ('SouthPole', 'July'))_GS-ice_alpha=0.67",
#  "ZatsepinSokolskaya default_MCEq_atm-DPMJETIII191-('MSIS00', ('SouthPole', 'July'))_GS-ice_alpha=0.67",
#  "GaisserHonda_MCEq_atm-DPMJETIII191-('MSIS00', ('SouthPole', 'July'))_GS-ice_alpha=0.67",
#  "Thunman_MCEq_atm-DPMJETIII191-('MSIS00', ('SouthPole', 'July'))_GS-ice_alpha=0.67",
#  "SimplePowerlaw27_MCEq_atm-DPMJETIII191-('MSIS00', ('SouthPole', 'July'))_GS-ice_alpha=0.67",
#  'JN-fit_MCEq_mu_ice-Heisinger-False_alpha=0.67',
#  'daemonflux_MCEq_mu_ice-Heisinger-False_alpha=0.67',
#  "GlobalSplineFitBeta_MCEq_atm-SIBYLL23CPP-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "HillasGaisser2012 H3a_MCEq_atm-SIBYLL23CPP-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "HillasGaisser2012 H4a_MCEq_atm-SIBYLL23CPP-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "PolyGonato_MCEq_atm-SIBYLL23CPP-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "GaisserStanevTilav 3-gen_MCEq_atm-SIBYLL23CPP-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "GaisserStanevTilav 4-gen_MCEq_atm-SIBYLL23CPP-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "CombinedGHandHG H3a_MCEq_atm-SIBYLL23CPP-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "ZatsepinSokolskaya pamela_MCEq_atm-SIBYLL23CPP-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "ZatsepinSokolskaya default_MCEq_atm-SIBYLL23CPP-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "GaisserHonda_MCEq_atm-SIBYLL23CPP-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "Thunman_MCEq_atm-SIBYLL23CPP-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "SimplePowerlaw27_MCEq_atm-SIBYLL23CPP-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "GlobalSplineFitBeta_MCEq_atm-SIBYLL23C03-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "HillasGaisser2012 H3a_MCEq_atm-SIBYLL23C03-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "HillasGaisser2012 H4a_MCEq_atm-SIBYLL23C03-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "PolyGonato_MCEq_atm-SIBYLL23C03-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "GaisserStanevTilav 3-gen_MCEq_atm-SIBYLL23C03-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "GaisserStanevTilav 4-gen_MCEq_atm-SIBYLL23C03-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "CombinedGHandHG H3a_MCEq_atm-SIBYLL23C03-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "ZatsepinSokolskaya pamela_MCEq_atm-SIBYLL23C03-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "ZatsepinSokolskaya default_MCEq_atm-SIBYLL23C03-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "GaisserHonda_MCEq_atm-SIBYLL23C03-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "Thunman_MCEq_atm-SIBYLL23C03-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "SimplePowerlaw27_MCEq_atm-SIBYLL23C03-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "GlobalSplineFitBeta_MCEq_atm-SIBYLL-2.3c-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "HillasGaisser2012 H3a_MCEq_atm-SIBYLL-2.3c-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "HillasGaisser2012 H4a_MCEq_atm-SIBYLL-2.3c-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "PolyGonato_MCEq_atm-SIBYLL-2.3c-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "GaisserStanevTilav 3-gen_MCEq_atm-SIBYLL-2.3c-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "GaisserStanevTilav 4-gen_MCEq_atm-SIBYLL-2.3c-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "CombinedGHandHG H3a_MCEq_atm-SIBYLL-2.3c-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "ZatsepinSokolskaya pamela_MCEq_atm-SIBYLL-2.3c-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "ZatsepinSokolskaya default_MCEq_atm-SIBYLL-2.3c-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "GaisserHonda_MCEq_atm-SIBYLL-2.3c-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "Thunman_MCEq_atm-SIBYLL-2.3c-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "SimplePowerlaw27_MCEq_atm-SIBYLL-2.3c-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "GlobalSplineFitBeta_MCEq_atm-SIBYLL-2.3-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "HillasGaisser2012 H3a_MCEq_atm-SIBYLL-2.3-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "HillasGaisser2012 H4a_MCEq_atm-SIBYLL-2.3-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "PolyGonato_MCEq_atm-SIBYLL-2.3-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "GaisserStanevTilav 3-gen_MCEq_atm-SIBYLL-2.3-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "GaisserStanevTilav 4-gen_MCEq_atm-SIBYLL-2.3-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "CombinedGHandHG H3a_MCEq_atm-SIBYLL-2.3-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "ZatsepinSokolskaya pamela_MCEq_atm-SIBYLL-2.3-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "ZatsepinSokolskaya default_MCEq_atm-SIBYLL-2.3-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "GaisserHonda_MCEq_atm-SIBYLL-2.3-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "Thunman_MCEq_atm-SIBYLL-2.3-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "SimplePowerlaw27_MCEq_atm-SIBYLL-2.3-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "GlobalSplineFitBeta_MCEq_atm-SIBYLL-2.1-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "HillasGaisser2012 H3a_MCEq_atm-SIBYLL-2.1-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "HillasGaisser2012 H4a_MCEq_atm-SIBYLL-2.1-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "PolyGonato_MCEq_atm-SIBYLL-2.1-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "GaisserStanevTilav 3-gen_MCEq_atm-SIBYLL-2.1-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "GaisserStanevTilav 4-gen_MCEq_atm-SIBYLL-2.1-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "CombinedGHandHG H3a_MCEq_atm-SIBYLL-2.1-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "ZatsepinSokolskaya pamela_MCEq_atm-SIBYLL-2.1-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "ZatsepinSokolskaya default_MCEq_atm-SIBYLL-2.1-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "GaisserHonda_MCEq_atm-SIBYLL-2.1-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "Thunman_MCEq_atm-SIBYLL-2.1-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "SimplePowerlaw27_MCEq_atm-SIBYLL-2.1-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "GlobalSplineFitBeta_MCEq_atm-EPOS-LHC-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "HillasGaisser2012 H3a_MCEq_atm-EPOS-LHC-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "HillasGaisser2012 H4a_MCEq_atm-EPOS-LHC-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "PolyGonato_MCEq_atm-EPOS-LHC-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "GaisserStanevTilav 3-gen_MCEq_atm-EPOS-LHC-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "GaisserStanevTilav 4-gen_MCEq_atm-EPOS-LHC-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "CombinedGHandHG H3a_MCEq_atm-EPOS-LHC-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "ZatsepinSokolskaya pamela_MCEq_atm-EPOS-LHC-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "ZatsepinSokolskaya default_MCEq_atm-EPOS-LHC-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "GaisserHonda_MCEq_atm-EPOS-LHC-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "Thunman_MCEq_atm-EPOS-LHC-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "SimplePowerlaw27_MCEq_atm-EPOS-LHC-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "GlobalSplineFitBeta_MCEq_atm-QGSJET-II-04-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "HillasGaisser2012 H3a_MCEq_atm-QGSJET-II-04-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "HillasGaisser2012 H4a_MCEq_atm-QGSJET-II-04-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "PolyGonato_MCEq_atm-QGSJET-II-04-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "GaisserStanevTilav 3-gen_MCEq_atm-QGSJET-II-04-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "GaisserStanevTilav 4-gen_MCEq_atm-QGSJET-II-04-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "CombinedGHandHG H3a_MCEq_atm-QGSJET-II-04-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "ZatsepinSokolskaya pamela_MCEq_atm-QGSJET-II-04-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "ZatsepinSokolskaya default_MCEq_atm-QGSJET-II-04-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "GaisserHonda_MCEq_atm-QGSJET-II-04-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "Thunman_MCEq_atm-QGSJET-II-04-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "SimplePowerlaw27_MCEq_atm-QGSJET-II-04-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "GlobalSplineFitBeta_MCEq_atm-QGSJETII03-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "HillasGaisser2012 H3a_MCEq_atm-QGSJETII03-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "HillasGaisser2012 H4a_MCEq_atm-QGSJETII03-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "PolyGonato_MCEq_atm-QGSJETII03-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "GaisserStanevTilav 3-gen_MCEq_atm-QGSJETII03-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "GaisserStanevTilav 4-gen_MCEq_atm-QGSJETII03-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "CombinedGHandHG H3a_MCEq_atm-QGSJETII03-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "ZatsepinSokolskaya pamela_MCEq_atm-QGSJETII03-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "ZatsepinSokolskaya default_MCEq_atm-QGSJETII03-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "GaisserHonda_MCEq_atm-QGSJETII03-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "Thunman_MCEq_atm-QGSJETII03-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "SimplePowerlaw27_MCEq_atm-QGSJETII03-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "GlobalSplineFitBeta_MCEq_atm-QGSJET01C-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "HillasGaisser2012 H3a_MCEq_atm-QGSJET01C-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "HillasGaisser2012 H4a_MCEq_atm-QGSJET01C-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "PolyGonato_MCEq_atm-QGSJET01C-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "GaisserStanevTilav 3-gen_MCEq_atm-QGSJET01C-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "GaisserStanevTilav 4-gen_MCEq_atm-QGSJET01C-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "CombinedGHandHG H3a_MCEq_atm-QGSJET01C-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "ZatsepinSokolskaya pamela_MCEq_atm-QGSJET01C-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "ZatsepinSokolskaya default_MCEq_atm-QGSJET01C-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "GaisserHonda_MCEq_atm-QGSJET01C-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "Thunman_MCEq_atm-QGSJET01C-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "SimplePowerlaw27_MCEq_atm-QGSJET01C-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "GlobalSplineFitBeta_MCEq_atm-DPMJETIII306-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "HillasGaisser2012 H3a_MCEq_atm-DPMJETIII306-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "HillasGaisser2012 H4a_MCEq_atm-DPMJETIII306-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "PolyGonato_MCEq_atm-DPMJETIII306-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "GaisserStanevTilav 3-gen_MCEq_atm-DPMJETIII306-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "GaisserStanevTilav 4-gen_MCEq_atm-DPMJETIII306-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "CombinedGHandHG H3a_MCEq_atm-DPMJETIII306-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "ZatsepinSokolskaya pamela_MCEq_atm-DPMJETIII306-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "ZatsepinSokolskaya default_MCEq_atm-DPMJETIII306-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "GaisserHonda_MCEq_atm-DPMJETIII306-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "Thunman_MCEq_atm-DPMJETIII306-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "SimplePowerlaw27_MCEq_atm-DPMJETIII306-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "GlobalSplineFitBeta_MCEq_atm-DPMJETIII191-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "HillasGaisser2012 H3a_MCEq_atm-DPMJETIII191-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "HillasGaisser2012 H4a_MCEq_atm-DPMJETIII191-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "PolyGonato_MCEq_atm-DPMJETIII191-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "GaisserStanevTilav 3-gen_MCEq_atm-DPMJETIII191-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "GaisserStanevTilav 4-gen_MCEq_atm-DPMJETIII191-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "CombinedGHandHG H3a_MCEq_atm-DPMJETIII191-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "ZatsepinSokolskaya pamela_MCEq_atm-DPMJETIII191-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "ZatsepinSokolskaya default_MCEq_atm-DPMJETIII191-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "GaisserHonda_MCEq_atm-DPMJETIII191-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "Thunman_MCEq_atm-DPMJETIII191-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "SimplePowerlaw27_MCEq_atm-DPMJETIII191-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "GlobalSplineFitBeta_MCEq_atm-SIBYLL23CPP-('MSIS00', ('SouthPole', 'July'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "HillasGaisser2012 H3a_MCEq_atm-SIBYLL23CPP-('MSIS00', ('SouthPole', 'July'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "HillasGaisser2012 H4a_MCEq_atm-SIBYLL23CPP-('MSIS00', ('SouthPole', 'July'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "PolyGonato_MCEq_atm-SIBYLL23CPP-('MSIS00', ('SouthPole', 'July'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "GaisserStanevTilav 3-gen_MCEq_atm-SIBYLL23CPP-('MSIS00', ('SouthPole', 'July'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "GaisserStanevTilav 4-gen_MCEq_atm-SIBYLL23CPP-('MSIS00', ('SouthPole', 'July'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "CombinedGHandHG H3a_MCEq_atm-SIBYLL23CPP-('MSIS00', ('SouthPole', 'July'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "ZatsepinSokolskaya pamela_MCEq_atm-SIBYLL23CPP-('MSIS00', ('SouthPole', 'July'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "ZatsepinSokolskaya default_MCEq_atm-SIBYLL23CPP-('MSIS00', ('SouthPole', 'July'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "GaisserHonda_MCEq_atm-SIBYLL23CPP-('MSIS00', ('SouthPole', 'July'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "Thunman_MCEq_atm-SIBYLL23CPP-('MSIS00', ('SouthPole', 'July'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "SimplePowerlaw27_MCEq_atm-SIBYLL23CPP-('MSIS00', ('SouthPole', 'July'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "GlobalSplineFitBeta_MCEq_atm-SIBYLL23C03-('MSIS00', ('SouthPole', 'July'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "HillasGaisser2012 H3a_MCEq_atm-SIBYLL23C03-('MSIS00', ('SouthPole', 'July'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "HillasGaisser2012 H4a_MCEq_atm-SIBYLL23C03-('MSIS00', ('SouthPole', 'July'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "PolyGonato_MCEq_atm-SIBYLL23C03-('MSIS00', ('SouthPole', 'July'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "GaisserStanevTilav 3-gen_MCEq_atm-SIBYLL23C03-('MSIS00', ('SouthPole', 'July'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "GaisserStanevTilav 4-gen_MCEq_atm-SIBYLL23C03-('MSIS00', ('SouthPole', 'July'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "CombinedGHandHG H3a_MCEq_atm-SIBYLL23C03-('MSIS00', ('SouthPole', 'July'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "ZatsepinSokolskaya pamela_MCEq_atm-SIBYLL23C03-('MSIS00', ('SouthPole', 'July'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "ZatsepinSokolskaya default_MCEq_atm-SIBYLL23C03-('MSIS00', ('SouthPole', 'July'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "GaisserHonda_MCEq_atm-SIBYLL23C03-('MSIS00', ('SouthPole', 'July'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "Thunman_MCEq_atm-SIBYLL23C03-('MSIS00', ('SouthPole', 'July'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "SimplePowerlaw27_MCEq_atm-SIBYLL23C03-('MSIS00', ('SouthPole', 'July'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "GlobalSplineFitBeta_MCEq_atm-SIBYLL-2.3c-('MSIS00', ('SouthPole', 'July'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "HillasGaisser2012 H3a_MCEq_atm-SIBYLL-2.3c-('MSIS00', ('SouthPole', 'July'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "HillasGaisser2012 H4a_MCEq_atm-SIBYLL-2.3c-('MSIS00', ('SouthPole', 'July'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "PolyGonato_MCEq_atm-SIBYLL-2.3c-('MSIS00', ('SouthPole', 'July'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "GaisserStanevTilav 3-gen_MCEq_atm-SIBYLL-2.3c-('MSIS00', ('SouthPole', 'July'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "GaisserStanevTilav 4-gen_MCEq_atm-SIBYLL-2.3c-('MSIS00', ('SouthPole', 'July'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "CombinedGHandHG H3a_MCEq_atm-SIBYLL-2.3c-('MSIS00', ('SouthPole', 'July'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "ZatsepinSokolskaya pamela_MCEq_atm-SIBYLL-2.3c-('MSIS00', ('SouthPole', 'July'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "ZatsepinSokolskaya default_MCEq_atm-SIBYLL-2.3c-('MSIS00', ('SouthPole', 'July'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "GaisserHonda_MCEq_atm-SIBYLL-2.3c-('MSIS00', ('SouthPole', 'July'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "Thunman_MCEq_atm-SIBYLL-2.3c-('MSIS00', ('SouthPole', 'July'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "SimplePowerlaw27_MCEq_atm-SIBYLL-2.3c-('MSIS00', ('SouthPole', 'July'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "GlobalSplineFitBeta_MCEq_atm-SIBYLL-2.3-('MSIS00', ('SouthPole', 'July'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "HillasGaisser2012 H3a_MCEq_atm-SIBYLL-2.3-('MSIS00', ('SouthPole', 'July'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "HillasGaisser2012 H4a_MCEq_atm-SIBYLL-2.3-('MSIS00', ('SouthPole', 'July'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "PolyGonato_MCEq_atm-SIBYLL-2.3-('MSIS00', ('SouthPole', 'July'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "GaisserStanevTilav 3-gen_MCEq_atm-SIBYLL-2.3-('MSIS00', ('SouthPole', 'July'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "GaisserStanevTilav 4-gen_MCEq_atm-SIBYLL-2.3-('MSIS00', ('SouthPole', 'July'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "CombinedGHandHG H3a_MCEq_atm-SIBYLL-2.3-('MSIS00', ('SouthPole', 'July'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "ZatsepinSokolskaya pamela_MCEq_atm-SIBYLL-2.3-('MSIS00', ('SouthPole', 'July'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "ZatsepinSokolskaya default_MCEq_atm-SIBYLL-2.3-('MSIS00', ('SouthPole', 'July'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "GaisserHonda_MCEq_atm-SIBYLL-2.3-('MSIS00', ('SouthPole', 'July'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "Thunman_MCEq_atm-SIBYLL-2.3-('MSIS00', ('SouthPole', 'July'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "SimplePowerlaw27_MCEq_atm-SIBYLL-2.3-('MSIS00', ('SouthPole', 'July'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "GlobalSplineFitBeta_MCEq_atm-SIBYLL-2.1-('MSIS00', ('SouthPole', 'July'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "HillasGaisser2012 H3a_MCEq_atm-SIBYLL-2.1-('MSIS00', ('SouthPole', 'July'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "HillasGaisser2012 H4a_MCEq_atm-SIBYLL-2.1-('MSIS00', ('SouthPole', 'July'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#  "PolyGonato_MCEq_atm-SIBYLL-2.1-('MSIS00', ('SouthPole', 'July'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
# ...
#  "GlobalSplineFitBeta_MCEq_atm-EPOS-LHC-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-None-False_alpha=0.67",
#  "HillasGaisser2012 H3a_MCEq_atm-EPOS-LHC-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-None-False_alpha=0.67",
#  "HillasGaisser2012 H4a_MCEq_atm-EPOS-LHC-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-None-False_alpha=0.67",
#  "PolyGonato_MCEq_atm-EPOS-LHC-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-None-False_alpha=0.67",
#  "GaisserStanevTilav 3-gen_MCEq_atm-EPOS-LHC-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-None-False_alpha=0.67",
#  "GaisserStanevTilav 4-gen_MCEq_atm-EPOS-LHC-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-None-False_alpha=0.67",
#  "CombinedGHandHG H3a_MCEq_atm-EPOS-LHC-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-None-False_alpha=0.67",
#  "ZatsepinSokolskaya pamela_MCEq_atm-EPOS-LHC-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-None-False_alpha=0.67",
#  "ZatsepinSokolskaya default_MCEq_atm-EPOS-LHC-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-None-False_alpha=0.67",
#  "GaisserHonda_MCEq_atm-EPOS-LHC-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-None-False_alpha=0.67",
#  "Thunman_MCEq_atm-EPOS-LHC-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-None-False_alpha=0.67",
#  "SimplePowerlaw27_MCEq_atm-EPOS-LHC-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-None-False_alpha=0.67",
#  "GlobalSplineFitBeta_MCEq_atm-QGSJET-II-04-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-None-False_alpha=0.67",
#  "HillasGaisser2012 H3a_MCEq_atm-QGSJET-II-04-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-None-False_alpha=0.67",
#  "HillasGaisser2012 H4a_MCEq_atm-QGSJET-II-04-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-None-False_alpha=0.67",
#  "PolyGonato_MCEq_atm-QGSJET-II-04-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-None-False_alpha=0.67",
#  "GaisserStanevTilav 3-gen_MCEq_atm-QGSJET-II-04-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-None-False_alpha=0.67",
#  "GaisserStanevTilav 4-gen_MCEq_atm-QGSJET-II-04-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-None-False_alpha=0.67",
#  "CombinedGHandHG H3a_MCEq_atm-QGSJET-II-04-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-None-False_alpha=0.67",
#  "ZatsepinSokolskaya pamela_MCEq_atm-QGSJET-II-04-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-None-False_alpha=0.67",
#  "ZatsepinSokolskaya default_MCEq_atm-QGSJET-II-04-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-None-False_alpha=0.67",
#  "GaisserHonda_MCEq_atm-QGSJET-II-04-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-None-False_alpha=0.67",
#  "Thunman_MCEq_atm-QGSJET-II-04-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-None-False_alpha=0.67",
#  "SimplePowerlaw27_MCEq_atm-QGSJET-II-04-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-None-False_alpha=0.67",
#  "GlobalSplineFitBeta_MCEq_atm-QGSJETII03-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-None-False_alpha=0.67",
#  "HillasGaisser2012 H3a_MCEq_atm-QGSJETII03-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-None-False_alpha=0.67",
#  "HillasGaisser2012 H4a_MCEq_atm-QGSJETII03-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-None-False_alpha=0.67",
#  "PolyGonato_MCEq_atm-QGSJETII03-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-None-False_alpha=0.67",
#  "GaisserStanevTilav 3-gen_MCEq_atm-QGSJETII03-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-None-False_alpha=0.67",
#  "GaisserStanevTilav 4-gen_MCEq_atm-QGSJETII03-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-None-False_alpha=0.67",
#  "CombinedGHandHG H3a_MCEq_atm-QGSJETII03-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-None-False_alpha=0.67",
#  "ZatsepinSokolskaya pamela_MCEq_atm-QGSJETII03-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-None-False_alpha=0.67",
#  "ZatsepinSokolskaya default_MCEq_atm-QGSJETII03-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-None-False_alpha=0.67",
#  "GaisserHonda_MCEq_atm-QGSJETII03-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-None-False_alpha=0.67",
#  "Thunman_MCEq_atm-QGSJETII03-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-None-False_alpha=0.67",
#  "SimplePowerlaw27_MCEq_atm-QGSJETII03-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-None-False_alpha=0.67",
#  "GlobalSplineFitBeta_MCEq_atm-QGSJET01C-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-None-False_alpha=0.67",
#  "HillasGaisser2012 H3a_MCEq_atm-QGSJET01C-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-None-False_alpha=0.67",
#  "HillasGaisser2012 H4a_MCEq_atm-QGSJET01C-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-None-False_alpha=0.67",
#  "PolyGonato_MCEq_atm-QGSJET01C-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-None-False_alpha=0.67",
#  "GaisserStanevTilav 3-gen_MCEq_atm-QGSJET01C-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-None-False_alpha=0.67",
#  "GaisserStanevTilav 4-gen_MCEq_atm-QGSJET01C-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-None-False_alpha=0.67",
#  "CombinedGHandHG H3a_MCEq_atm-QGSJET01C-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-None-False_alpha=0.67",
#  "ZatsepinSokolskaya pamela_MCEq_atm-QGSJET01C-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-None-False_alpha=0.67",
#  "ZatsepinSokolskaya default_MCEq_atm-QGSJET01C-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-None-False_alpha=0.67",
#  "GaisserHonda_MCEq_atm-QGSJET01C-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-None-False_alpha=0.67",
#  "Thunman_MCEq_atm-QGSJET01C-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-None-False_alpha=0.67",
#  "SimplePowerlaw27_MCEq_atm-QGSJET01C-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-None-False_alpha=0.67",
#  "GlobalSplineFitBeta_MCEq_atm-DPMJETIII306-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-None-False_alpha=0.67",
#  "HillasGaisser2012 H3a_MCEq_atm-DPMJETIII306-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-None-False_alpha=0.67",
#  "HillasGaisser2012 H4a_MCEq_atm-DPMJETIII306-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-None-False_alpha=0.67",
#  "PolyGonato_MCEq_atm-DPMJETIII306-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-None-False_alpha=0.67",
#  "GaisserStanevTilav 3-gen_MCEq_atm-DPMJETIII306-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-None-False_alpha=0.67",
#  "GaisserStanevTilav 4-gen_MCEq_atm-DPMJETIII306-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-None-False_alpha=0.67",
#  "CombinedGHandHG H3a_MCEq_atm-DPMJETIII306-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-None-False_alpha=0.67",
#  "ZatsepinSokolskaya pamela_MCEq_atm-DPMJETIII306-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-None-False_alpha=0.67",
#  "ZatsepinSokolskaya default_MCEq_atm-DPMJETIII306-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-None-False_alpha=0.67",
#  "GaisserHonda_MCEq_atm-DPMJETIII306-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-None-False_alpha=0.67",
#  "Thunman_MCEq_atm-DPMJETIII306-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-None-False_alpha=0.67",
#  "SimplePowerlaw27_MCEq_atm-DPMJETIII306-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-None-False_alpha=0.67",
#  "GlobalSplineFitBeta_MCEq_atm-DPMJETIII191-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-None-False_alpha=0.67",
#  "HillasGaisser2012 H3a_MCEq_atm-DPMJETIII191-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-None-False_alpha=0.67",
#  "HillasGaisser2012 H4a_MCEq_atm-DPMJETIII191-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-None-False_alpha=0.67",
#  "PolyGonato_MCEq_atm-DPMJETIII191-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-None-False_alpha=0.67",
#  "GaisserStanevTilav 3-gen_MCEq_atm-DPMJETIII191-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-None-False_alpha=0.67",
#  "GaisserStanevTilav 4-gen_MCEq_atm-DPMJETIII191-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-None-False_alpha=0.67",
#  "CombinedGHandHG H3a_MCEq_atm-DPMJETIII191-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-None-False_alpha=0.67",
#  "ZatsepinSokolskaya pamela_MCEq_atm-DPMJETIII191-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-None-False_alpha=0.67",
#  "ZatsepinSokolskaya default_MCEq_atm-DPMJETIII191-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-None-False_alpha=0.67",
#  "GaisserHonda_MCEq_atm-DPMJETIII191-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-None-False_alpha=0.67",
#  "Thunman_MCEq_atm-DPMJETIII191-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-None-False_alpha=0.67",
#  "SimplePowerlaw27_MCEq_atm-DPMJETIII191-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-None-False_alpha=0.67",
#  "GlobalSplineFitBeta_MCEq_atm-SIBYLL23CPP-('MSIS00', ('SouthPole', 'July'))_MCEq_mu_ice-None-False_alpha=0.67",
#  "HillasGaisser2012 H3a_MCEq_atm-SIBYLL23CPP-('MSIS00', ('SouthPole', 'July'))_MCEq_mu_ice-None-False_alpha=0.67",
#  "HillasGaisser2012 H4a_MCEq_atm-SIBYLL23CPP-('MSIS00', ('SouthPole', 'July'))_MCEq_mu_ice-None-False_alpha=0.67",
#  "PolyGonato_MCEq_atm-SIBYLL23CPP-('MSIS00', ('SouthPole', 'July'))_MCEq_mu_ice-None-False_alpha=0.67",
#  "GaisserStanevTilav 3-gen_MCEq_atm-SIBYLL23CPP-('MSIS00', ('SouthPole', 'July'))_MCEq_mu_ice-None-False_alpha=0.67",
#  "GaisserStanevTilav 4-gen_MCEq_atm-SIBYLL23CPP-('MSIS00', ('SouthPole', 'July'))_MCEq_mu_ice-None-False_alpha=0.67",
#  "CombinedGHandHG H3a_MCEq_atm-SIBYLL23CPP-('MSIS00', ('SouthPole', 'July'))_MCEq_mu_ice-None-False_alpha=0.67",
#  "ZatsepinSokolskaya pamela_MCEq_atm-SIBYLL23CPP-('MSIS00', ('SouthPole', 'July'))_MCEq_mu_ice-None-False_alpha=0.67",
#  "ZatsepinSokolskaya default_MCEq_atm-SIBYLL23CPP-('MSIS00', ('SouthPole', 'July'))_MCEq_mu_ice-None-False_alpha=0.67",
#  "GaisserHonda_MCEq_atm-SIBYLL23CPP-('MSIS00', ('SouthPole', 'July'))_MCEq_mu_ice-None-False_alpha=0.67",
#  "Thunman_MCEq_atm-SIBYLL23CPP-('MSIS00', ('SouthPole', 'July'))_MCEq_mu_ice-None-False_alpha=0.67",
#  "SimplePowerlaw27_MCEq_atm-SIBYLL23CPP-('MSIS00', ('SouthPole', 'July'))_MCEq_mu_ice-None-False_alpha=0.67",
#  "GlobalSplineFitBeta_MCEq_atm-SIBYLL23C03-('MSIS00', ('SouthPole', 'July'))_MCEq_mu_ice-None-False_alpha=0.67",
#  "HillasGaisser2012 H3a_MCEq_atm-SIBYLL23C03-('MSIS00', ('SouthPole', 'July'))_MCEq_mu_ice-None-False_alpha=0.67",
#  "HillasGaisser2012 H4a_MCEq_atm-SIBYLL23C03-('MSIS00', ('SouthPole', 'July'))_MCEq_mu_ice-None-False_alpha=0.67",
#  "PolyGonato_MCEq_atm-SIBYLL23C03-('MSIS00', ('SouthPole', 'July'))_MCEq_mu_ice-None-False_alpha=0.67",
#  "GaisserStanevTilav 3-gen_MCEq_atm-SIBYLL23C03-('MSIS00', ('SouthPole', 'July'))_MCEq_mu_ice-None-False_alpha=0.67",
#  "GaisserStanevTilav 4-gen_MCEq_atm-SIBYLL23C03-('MSIS00', ('SouthPole', 'July'))_MCEq_mu_ice-None-False_alpha=0.67",
#  "CombinedGHandHG H3a_MCEq_atm-SIBYLL23C03-('MSIS00', ('SouthPole', 'July'))_MCEq_mu_ice-None-False_alpha=0.67",
#  "ZatsepinSokolskaya pamela_MCEq_atm-SIBYLL23C03-('MSIS00', ('SouthPole', 'July'))_MCEq_mu_ice-None-False_alpha=0.67",
#  "ZatsepinSokolskaya default_MCEq_atm-SIBYLL23C03-('MSIS00', ('SouthPole', 'July'))_MCEq_mu_ice-None-False_alpha=0.67",
#  "GaisserHonda_MCEq_atm-SIBYLL23C03-('MSIS00', ('SouthPole', 'July'))_MCEq_mu_ice-None-False_alpha=0.67",
#  "Thunman_MCEq_atm-SIBYLL23C03-('MSIS00', ('SouthPole', 'July'))_MCEq_mu_ice-None-False_alpha=0.67",
#  "SimplePowerlaw27_MCEq_atm-SIBYLL23C03-('MSIS00', ('SouthPole', 'July'))_MCEq_mu_ice-None-False_alpha=0.67",
#  "GlobalSplineFitBeta_MCEq_atm-SIBYLL-2.3c-('MSIS00', ('SouthPole', 'July'))_MCEq_mu_ice-None-False_alpha=0.67",
#  "HillasGaisser2012 H3a_MCEq_atm-SIBYLL-2.3c-('MSIS00', ('SouthPole', 'July'))_MCEq_mu_ice-None-False_alpha=0.67",
#  "HillasGaisser2012 H4a_MCEq_atm-SIBYLL-2.3c-('MSIS00', ('SouthPole', 'July'))_MCEq_mu_ice-None-False_alpha=0.67",
#  "PolyGonato_MCEq_atm-SIBYLL-2.3c-('MSIS00', ('SouthPole', 'July'))_MCEq_mu_ice-None-False_alpha=0.67",
#  "GaisserStanevTilav 3-gen_MCEq_atm-SIBYLL-2.3c-('MSIS00', ('SouthPole', 'July'))_MCEq_mu_ice-None-False_alpha=0.67",
#  "GaisserStanevTilav 4-gen_MCEq_atm-SIBYLL-2.3c-('MSIS00', ('SouthPole', 'July'))_MCEq_mu_ice-None-False_alpha=0.67",
#  "CombinedGHandHG H3a_MCEq_atm-SIBYLL-2.3c-('MSIS00', ('SouthPole', 'July'))_MCEq_mu_ice-None-False_alpha=0.67",
#  "ZatsepinSokolskaya pamela_MCEq_atm-SIBYLL-2.3c-('MSIS00', ('SouthPole', 'July'))_MCEq_mu_ice-None-False_alpha=0.67",
#  "ZatsepinSokolskaya default_MCEq_atm-SIBYLL-2.3c-('MSIS00', ('SouthPole', 'July'))_MCEq_mu_ice-None-False_alpha=0.67",
#  "GaisserHonda_MCEq_atm-SIBYLL-2.3c-('MSIS00', ('SouthPole', 'July'))_MCEq_mu_ice-None-False_alpha=0.67",
#  "Thunman_MCEq_atm-SIBYLL-2.3c-('MSIS00', ('SouthPole', 'July'))_MCEq_mu_ice-None-False_alpha=0.67",
#  "SimplePowerlaw27_MCEq_atm-SIBYLL-2.3c-('MSIS00', ('SouthPole', 'July'))_MCEq_mu_ice-None-False_alpha=0.67",
#  "GlobalSplineFitBeta_MCEq_atm-SIBYLL-2.3-('MSIS00', ('SouthPole', 'July'))_MCEq_mu_ice-None-False_alpha=0.67",
#  "HillasGaisser2012 H3a_MCEq_atm-SIBYLL-2.3-('MSIS00', ('SouthPole', 'July'))_MCEq_mu_ice-None-False_alpha=0.67",
#  "HillasGaisser2012 H4a_MCEq_atm-SIBYLL-2.3-('MSIS00', ('SouthPole', 'July'))_MCEq_mu_ice-None-False_alpha=0.67",
#  "PolyGonato_MCEq_atm-SIBYLL-2.3-('MSIS00', ('SouthPole', 'July'))_MCEq_mu_ice-None-False_alpha=0.67",
#  "GaisserStanevTilav 3-gen_MCEq_atm-SIBYLL-2.3-('MSIS00', ('SouthPole', 'July'))_MCEq_mu_ice-None-False_alpha=0.67",
#  "GaisserStanevTilav 4-gen_MCEq_atm-SIBYLL-2.3-('MSIS00', ('SouthPole', 'July'))_MCEq_mu_ice-None-False_alpha=0.67",
#  "CombinedGHandHG H3a_MCEq_atm-SIBYLL-2.3-('MSIS00', ('SouthPole', 'July'))_MCEq_mu_ice-None-False_alpha=0.67",
#  "ZatsepinSokolskaya pamela_MCEq_atm-SIBYLL-2.3-('MSIS00', ('SouthPole', 'July'))_MCEq_mu_ice-None-False_alpha=0.67",
#  "ZatsepinSokolskaya default_MCEq_atm-SIBYLL-2.3-('MSIS00', ('SouthPole', 'July'))_MCEq_mu_ice-None-False_alpha=0.67",
#  "GaisserHonda_MCEq_atm-SIBYLL-2.3-('MSIS00', ('SouthPole', 'July'))_MCEq_mu_ice-None-False_alpha=0.67",
#  "Thunman_MCEq_atm-SIBYLL-2.3-('MSIS00', ('SouthPole', 'July'))_MCEq_mu_ice-None-False_alpha=0.67",
#  "SimplePowerlaw27_MCEq_atm-SIBYLL-2.3-('MSIS00', ('SouthPole', 'July'))_MCEq_mu_ice-None-False_alpha=0.67",
#  "GlobalSplineFitBeta_MCEq_atm-SIBYLL-2.1-('MSIS00', ('SouthPole', 'July'))_MCEq_mu_ice-None-False_alpha=0.67",
#  "HillasGaisser2012 H3a_MCEq_atm-SIBYLL-2.1-('MSIS00', ('SouthPole', 'July'))_MCEq_mu_ice-None-False_alpha=0.67",
#  "HillasGaisser2012 H4a_MCEq_atm-SIBYLL-2.1-('MSIS00', ('SouthPole', 'July'))_MCEq_mu_ice-None-False_alpha=0.67",
#  "PolyGonato_MCEq_atm-SIBYLL-2.1-('MSIS00', ('SouthPole', 'July'))_MCEq_mu_ice-None-False_alpha=0.67",
#  "GaisserStanevTilav 3-gen_MCEq_atm-SIBYLL-2.1-('MSIS00', ('SouthPole', 'July'))_MCEq_mu_ice-None-False_alpha=0.67",
#  "GaisserStanevTilav 4-gen_MCEq_atm-SIBYLL-2.1-('MSIS00', ('SouthPole', 'July'))_MCEq_mu_ice-None-False_alpha=0.67",
#  "CombinedGHandHG H3a_MCEq_atm-SIBYLL-2.1-('MSIS00', ('SouthPole', 'July'))_MCEq_mu_ice-None-False_alpha=0.67",
#  "ZatsepinSokolskaya pamela_MCEq_atm-SIBYLL-2.1-('MSIS00', ('SouthPole', 'July'))_MCEq_mu_ice-None-False_alpha=0.67",
#  "ZatsepinSokolskaya default_MCEq_atm-SIBYLL-2.1-('MSIS00', ('SouthPole', 'July'))_MCEq_mu_ice-None-False_alpha=0.67",
#  "GaisserHonda_MCEq_atm-SIBYLL-2.1-('MSIS00', ('SouthPole', 'July'))_MCEq_mu_ice-None-False_alpha=0.67",
#  "Thunman_MCEq_atm-SIBYLL-2.1-('MSIS00', ('SouthPole', 'July'))_MCEq_mu_ice-None-False_alpha=0.67",
#  "SimplePowerlaw27_MCEq_atm-SIBYLL-2.1-('MSIS00', ('SouthPole', 'July'))_MCEq_mu_ice-None-False_alpha=0.67",
#  "GlobalSplineFitBeta_MCEq_atm-EPOS-LHC-('MSIS00', ('SouthPole', 'July'))_MCEq_mu_ice-None-False_alpha=0.67",
#  "HillasGaisser2012 H3a_MCEq_atm-EPOS-LHC-('MSIS00', ('SouthPole', 'July'))_MCEq_mu_ice-None-False_alpha=0.67",
#  "HillasGaisser2012 H4a_MCEq_atm-EPOS-LHC-('MSIS00', ('SouthPole', 'July'))_MCEq_mu_ice-None-False_alpha=0.67",
#  "PolyGonato_MCEq_atm-EPOS-LHC-('MSIS00', ('SouthPole', 'July'))_MCEq_mu_ice-None-False_alpha=0.67",
#  "GaisserStanevTilav 3-gen_MCEq_atm-EPOS-LHC-('MSIS00', ('SouthPole', 'July'))_MCEq_mu_ice-None-False_alpha=0.67",
#  "GaisserStanevTilav 4-gen_MCEq_atm-EPOS-LHC-('MSIS00', ('SouthPole', 'July'))_MCEq_mu_ice-None-False_alpha=0.67",
#  "CombinedGHandHG H3a_MCEq_atm-EPOS-LHC-('MSIS00', ('SouthPole', 'July'))_MCEq_mu_ice-None-False_alpha=0.67",
#  "ZatsepinSokolskaya pamela_MCEq_atm-EPOS-LHC-('MSIS00', ('SouthPole', 'July'))_MCEq_mu_ice-None-False_alpha=0.67",
#  ...]

# %%
(len(model_names)-1)//len(alphas)
# Out:
# 2660

# %%
N_alphas = len(alphas)
N_ice = 10
N_atmFit = 2
N_atm = 2
N_int = 11
N_primary = 12

# %%
models_MCEq = np.reshape(model_names[:-1], (N_alphas,N_ice,-1))[:,:,N_atmFit:].reshape((N_alphas,N_ice,N_atm,N_int,-1))
#axis0 - alpha
#axis1 - Underice Propagation Model
#axis2 - Month (Atmospheric Profile)
#axis3 - Interaction Model
#axis4 - Primary Model

# %%
models_atmFit = np.reshape(model_names[:-1], (N_alphas,N_ice,-1))[:,:,:N_atmFit]
#axis0 - alpha
#axis1 - Underice Propagation Model
#axis2 - Atmospheric Muon Flux Fit

# %%
P_14C_MCEq = P_14C[:-1].reshape((N_alphas,N_ice,-1,*P_14C.shape[1:]))[:,:,N_atmFit:].reshape((N_alphas,N_ice,N_atm,N_int,-1,*P_14C.shape[1:]))
#axis0 - alpha
#axis1 - Underice Propagation Model
#axis2 - Month (Atmospheric Profile)
#axis3 - Interaction Model
#axis4 - Primary Model
#axis5 - Production Mode
#axis6 - Depth
P_14C_MCEq.shape
# Out:
# (34, 10, 2, 11, 12, 2, 255)

# %%
P_14C_atmFit = P_14C[:-1].reshape((N_alphas,N_ice,-1,*P_14C.shape[1:]))[:,:,:N_atmFit]
#axis0 - alpha
#axis1 - Underice Propagation Model
#axis2 - Atmospheric Muon Flux Fit
#axis5 - Production Mode
#axis6 - Depth
P_14C_atmFit.shape
# Out:
# (34, 10, 2, 2, 255)

# %%
P_avg = np.average(P_14C, axis=0)
#dP_14C = (P_14C-P_avg).reshape((len(P_14C),-1))
#P_cov = np.moveaxis(((dP_14C.T @ dP_14C)/len(P_14C)).reshape((*P_14C.T.shape[:-1], *P_14C.shape[1:])), 0, -2)
P_cov = np.cov(P_14C.reshape(len(P_14C),-1), rowvar=False).reshape(*P_14C.shape[1:],*P_14C.shape[1:]).swapaxes(1,2)

# %%
np.shape(P_cov)
# Out:
# (2, 2, 255, 255)

# %%
plt.plot(np.sqrt(np.diag(P_cov[0,0]))/P_avg[0])
plt.plot(np.std(P_14C, axis=0)[0]/P_avg[0])

# %%
P_cov.shape
# Out:
# (2, 2, 255, 255)

# %%
alphas[8]
# Out:
# np.float64(0.7500000000000001)

# %%
P_cov.shape
# Out:
# (2, 2, 255, 255)

# %%
models_MCEq[0,:,0,0,0]
# Out:
# array(["GlobalSplineFitBeta_MCEq_atm-SIBYLL23CPP-('MSIS00', ('SouthPole', 'January'))_GS-ice_alpha=0.67",
#        "GlobalSplineFitBeta_MCEq_atm-SIBYLL23CPP-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-Heisinger-False_alpha=0.67",
#        "GlobalSplineFitBeta_MCEq_atm-SIBYLL23CPP-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-Heisinger-True_alpha=0.67",
#        "GlobalSplineFitBeta_MCEq_atm-SIBYLL23CPP-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-None-False_alpha=0.67",
#        "GlobalSplineFitBeta_MCEq_atm-SIBYLL23CPP-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-None-True_alpha=0.67",
#        "GlobalSplineFitBeta_MCEq_atm-SIBYLL23CPP-('MSIS00', ('SouthPole', 'January'))_GS-ice_H-norm_alpha=0.67",
#        "GlobalSplineFitBeta_MCEq_atm-SIBYLL23CPP-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-Heisinger-False_H-norm_alpha=0.67",
#        "GlobalSplineFitBeta_MCEq_atm-SIBYLL23CPP-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-Heisinger-True_H-norm_alpha=0.67",
#        "GlobalSplineFitBeta_MCEq_atm-SIBYLL23CPP-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-None-False_H-norm_alpha=0.67",
#        "GlobalSplineFitBeta_MCEq_atm-SIBYLL23CPP-('MSIS00', ('SouthPole', 'January'))_MCEq_mu_ice-None-True_H-norm_alpha=0.67"],
#       dtype='<U131')

# %%
def prod_plot(P_cut):
    P_cut_avg = np.mean(P_cut, axis=0)
    P_cut_cov = np.cov(P_cut.reshape(len(P_cut),-1), rowvar=False).reshape(*P_cut.shape[1:],*P_cut.shape[1:]).swapaxes(1,2)
    P_cut_std = np.sqrt([np.diag(P_cut_cov[0,0]), np.diag(P_cut_cov[1,1])])
    #plt.fill_between(Prop.z, P_avg[0]-np.sqrt(np.diag(P_cov[0,0])), P_avg[0]+np.sqrt(np.diag(P_cov[0,0])))
    #for i,p in enumerate(P_14C):
    fig, ((ax1, ax2), (ax3,ax4)) = plt.subplots(2,2, figsize=(12,8), tight_layout=True, sharex=True, sharey='row', height_ratios=[2,1])
    ax1.plot(Prop.z, P_cut.T[:,0], c='grey', alpha=np.clip(len(P_cut)**(-.6), min=5e-3))
    ax1.fill_between(Prop.z, P_cut_avg[0]-2*P_cut_std[0], P_cut_avg[0]+2*P_cut_std[0], alpha = 0.2, color='m', zorder=10)
    ax1.plot(Prop.z, P_cut_avg[0], c='m', ls='--', label=r'Avg. w/ 2$\sigma$', zorder=11)
    ax1.plot(Prop.z, P_14C[-1,0], ls='--', c='k', label='Heisinger')
    ax1.set(
        yscale='log',
        #ylim = (2e-4,2e1),
        ylabel=r'$^{14}$C Production Rate [atoms /g /yr]',
        title = r'Fast Muon Interactions'
    )
    ax1.legend(loc='upper right')
    #plt.title(r'Fast Muons $\alpha$={:.2f}'.format(alphas[i]))

    ax2.plot(Prop.z, P_cut.T[:,1], c='grey', alpha=np.clip(len(P_cut)**(-.6), min=5e-3))
    ax2.fill_between(Prop.z, P_cut_avg[1]-2*P_cut_std[1], P_cut_avg[1]+2*P_cut_std[1], alpha = 0.2, color='m', zorder=10)
    ax2.plot(Prop.z, P_cut_avg[1], c='m', ls='--', label=r'Avg. w/ 2$\sigma$', zorder=11)
    ax2.plot(Prop.z, P_14C[-1,1], ls='--', c='k', label='Heisinger')
    ax2.set(
        #yscale='log',
        #ylim = (3e-3,3),
        title = r'Negative Muon Capture'
    )
    ax2.legend(loc='upper right')

    rel = P_cut_avg
    #rel = P_14C[-1]
    ax3.plot(Prop.z, (P_cut[:,0]/rel[0]).T-1, c='grey', alpha=np.clip(len(P_cut)**(-.6), min=5e-3))
    ax3.fill_between(Prop.z, (P_cut_avg[0]-2*P_cut_std[0])/rel[0] -1, (P_cut_avg[0]+2*P_cut_std[0])/rel[0] -1, alpha = 0.2, color='m', zorder=10)
    ax3.plot(Prop.z, P_cut_avg[0]/rel[0]-1, c='m', ls='--', label=r'Avg. w/ 2$\sigma$', zorder=11)
    ax3.plot(Prop.z, P_14C[-1,0]/rel[0]-1, ls='--', c='k', label='Heisinger')
    ax3.set(
        xlabel='Depth [m]',
        xlim = (Prop.z[0],Prop.z[-1]),
        ylabel='Residual',
    )
    #plt.legend(loc='upper right')

    ax4.plot(Prop.z, (P_cut[:,1]/rel[1]).T-1, c='grey', alpha=np.clip(len(P_cut)**(-.6), min=5e-3))
    ax4.fill_between(Prop.z, (P_cut_avg[1]-2*P_cut_std[1])/rel[1] -1, (P_cut_avg[1]+2*P_cut_std[1])/rel[1] -1, alpha = 0.2, color='m', zorder=10)
    ax4.plot(Prop.z, P_cut_avg[1]/rel[1]-1, c='m', ls='--', label=r'Avg. w/ 2$\sigma$', zorder=11)
    ax4.plot(Prop.z, P_14C[-1,1]/rel[1]-1, ls='--', c='k', label='Heisinger')
    ax4.set(
        xlabel='Depth [m]',
    )
    #plt.legend(loc='upper right')
    
    return fig, ((ax1, ax2), (ax3,ax4))

# %%
fig, ((ax1, ax2), (ax3,ax4)) = prod_plot(P_14C)
plt.suptitle(r'Dome C Production Rates, All Models')
plt.show()

# %%
i = 8
fig, ((ax1, ax2), (ax3,ax4)) = prod_plot(P_14C_MCEq[i,:5].reshape(-1,2,len(Prop.z)))
plt.suptitle(r'Dome C Production Rates, MCEq + cont. energy loss, $\alpha$={:.2f}'.format(alphas[i]))
plt.show()

# %%
i = 8
fig, ((ax1, ax2), (ax3,ax4)) = prod_plot(P_14C_atmFit[i,:5].reshape(-1,2,len(Prop.z)))
plt.suptitle(r'Dome C Production Rates, Sea-Level Surface fit + cont. energy loss, $\alpha$={:.2f}'.format(alphas[i]))
plt.show()

# %%
i = 8
fig, ((ax1, ax2), (ax3,ax4)) = prod_plot(P_14C_MCEq[i,5:].reshape(-1,2,len(Prop.z)))
plt.suptitle(r'Dome C Production Rates, MCEq + cont. energy loss + Underground Total Flux fit, $\alpha$={:.2f}'.format(alphas[i]))
plt.show()

# %%
i = 8
fig, ((ax1, ax2), (ax3,ax4)) = prod_plot(P_14C_atmFit[i,5:].reshape(-1,2,len(Prop.z)))
plt.suptitle(r'Dome C Production Rates, Sea-Level Surface fit + cont. energy loss + Underground Total Flux fit, $\alpha$={:.2f}'.format(alphas[i]))
plt.show()

# %% [markdown]
# $$\hat{Z} = \hat{S}\hat{H}e^{\lambda \hat{t}}$$
#
# $\hat{H}$ - accumulation depth interpolation operator (interpolates production depths to h'(h,t))
#
# $$H(h') = (\frac{h'-h_{i-1}}{h_i-h_{i-1}}).\text{clip}(0,1) - (\frac{h'-h_{i}}{h_{i+1}-h_{i}}).\text{clip}(0,1)$$
#
# $h_i$ - propagation depths (for $i$<0 or $i$>max, replace the terms with $h'\geq h_0$ and $h'>h_{\text{max}}$, respectively)
#
# $\hat{S}$ - sample operator (averages over each sample depth range in accumulation depth)
#
# $$S(s,h) = \frac{(s^+ - h^-).\text{clip}(0,\Delta h) - (s^- - h^-).\text{clip}(0,\Delta h)}{\sum_h (s^+ - h^-).\text{clip}(0,\Delta h) - (s^- - h^-).\text{clip}(0,\Delta h)}$$
#
# $s$ - sample depth bins (+ upper bound, - lower bound)
#
# $h$ - accumulation depth bins (- lower bound, $\Delta$ width)

# %% [markdown]
# $h'(h,t)$ is given by the flowpaths from Taylor Glacier

# %%
h = Prop.h.reshape((-1,1,1)) # production depths
x = Prop.h_prime(Prop.h_accum.reshape((1,-1,1)), Prop.t_int.reshape((1,1,-1))) # accumulation depths

h_slope = ((x-h[:-1])/np.diff(h,axis=0)).clip(0,1) # slope from 0 to 1 as x passes from lower to upper bound
H = np.concatenate([1*(x>=h[0])-h_slope[0], -np.diff(h_slope, axis=0), h_slope[-1]-1*(x>h[-1])], axis=0)
#axis0 - production depth
#axis1 - accumulation depth
#axis2 - time

# %%
H.shape
# Out:
# (255, 183, 7296)

# %%
Prop.S_mat.shape
# Out:
# (183, 10)

# %%
#Z = np.moveaxis((H * np.exp(Prop.lambd * Prop.t_int.reshape((1,1,-1))) * Prop.dt_int.reshape((1,1,-1)))[Prop.z>Prop.z_close], 0, -1)
Z = np.einsum('kij,j->ijk', H[Prop.z>Prop.z_close], np.exp(Prop.lambd*Prop.t_int)*Prop.dt_int)

# %%
Z.shape
# Out:
# (183, 7296, 194)

# %%
Z_samp = (Z.T @ Prop.S_mat).T
#Z_samp = np.einsum('ai,ajk->ijk', Prop.S_mat, Z)

# %%
m_alpha = [m.split('_')[-1] for m in models_MCEq[:,0,0,0,0]]
m_alpha
# Out:
# ['alpha=0.67',
#  'alpha=0.68',
#  'alpha=0.69',
#  'alpha=0.70',
#  'alpha=0.71',
#  'alpha=0.72',
#  'alpha=0.73',
#  'alpha=0.74',
#  'alpha=0.75',
#  'alpha=0.76',
#  'alpha=0.77',
#  'alpha=0.78',
#  'alpha=0.79',
#  'alpha=0.80',
#  'alpha=0.81',
#  'alpha=0.82',
#  'alpha=0.83',
#  'alpha=0.84',
#  'alpha=0.85',
#  'alpha=0.86',
#  'alpha=0.87',
#  'alpha=0.88',
#  'alpha=0.89',
#  'alpha=0.90',
#  'alpha=0.91',
#  'alpha=0.92',
#  'alpha=0.93',
#  'alpha=0.94',
#  'alpha=0.95',
#  'alpha=0.96',
#  'alpha=0.97',
#  'alpha=0.98',
#  'alpha=0.99',
#  'alpha=1.00']

# %%
m_ice = [m.split('_')[-2] for m in models_MCEq[0,:,0,0,0]]
m_ice
# Out:
# ['GS-ice',
#  'ice-Heisinger-False',
#  'ice-Heisinger-True',
#  'ice-None-False',
#  'ice-None-True',
#  'H-norm',
#  'H-norm',
#  'H-norm',
#  'H-norm',
#  'H-norm']

# %%
m_atm = [m.split('_')[-3].split('-')[-1] for m in models_MCEq[0,0,:,0,0]]
m_atm
# Out:
# ["('MSIS00', ('SouthPole', 'January'))", "('MSIS00', ('SouthPole', 'July'))"]

# %%
m_int = [m.split('_')[-3].split('-')[1] for m in models_MCEq[0,0,0,:,0]]
m_int
# Out:
# ['SIBYLL23CPP',
#  'SIBYLL23C03',
#  'SIBYLL',
#  'SIBYLL',
#  'SIBYLL',
#  'EPOS',
#  'QGSJET',
#  'QGSJETII03',
#  'QGSJET01C',
#  'DPMJETIII306',
#  'DPMJETIII191']

# %%
m_primary = [m.split('_')[0] for m in models_MCEq[0,0,0,0,:]]
m_primary
# Out:
# ['GlobalSplineFitBeta',
#  'HillasGaisser2012 H3a',
#  'HillasGaisser2012 H4a',
#  'PolyGonato',
#  'GaisserStanevTilav 3-gen',
#  'GaisserStanevTilav 4-gen',
#  'CombinedGHandHG H3a',
#  'ZatsepinSokolskaya pamela',
#  'ZatsepinSokolskaya default',
#  'GaisserHonda',
#  'Thunman',
#  'SimplePowerlaw27']

# %%
alpha = np.array([0.75, 0.93])
dalpha = np.array([0.08, 0.07])

# %%
# weights on MCEq models
w_alpha = np.array([0.5,0.5]) # alpha
w_alphas = np.sum([np.exp(-((alphas-a)/dalpha[i])**2/2)/dalpha[i] * w_alpha[i] for i,a in enumerate(alpha)], axis=0)

w_ice = np.ones(models_MCEq.shape[1]) # ice propagation model
w_ice[5:] = 0.

w_atm = np.ones(models_MCEq.shape[2]) # atmospheric profile

w_int = np.ones(models_MCEq.shape[3]) # interaction model
w_int[:1] = 0.

w_primary = np.ones(models_MCEq.shape[4]) # primary model
w_primary[3:] = 0.

w_MCEq = w_alphas.reshape((-1,1,1,1,1)) * w_ice.reshape((1,-1,1,1,1)) * w_atm.reshape((1,1,-1,1,1)) * w_int.reshape((1,1,1,-1,1)) * w_primary.reshape((1,1,1,1,-1))
w_MCEq /= np.sum(w_MCEq) # normalize the weights

# %%
i=8
P_075 = P_14C_MCEq[i].reshape((-1,2,len(Prop.z)))
w_075 = w_MCEq[i].reshape((-1))
w_075 /= np.sum(w_075)
Sigma_075 = np.cov(P_075.reshape(len(P_075),-1), aweights=w_075, rowvar=False).reshape(*P_075.shape[1:],*P_075.shape[1:]).swapaxes(1,2)
alpha_075_cut = (alphas<=(alpha[0]+dalpha[0])) * (alphas>=(alpha[0]-dalpha[0])) * ~np.isclose(alphas, alpha[0])
P_075_range = P_14C_MCEq[alpha_075_cut].reshape((np.sum(alpha_075_cut),-1,2,len(Prop.z)))
dP_075_da = np.average((P_075_range - P_075)/(alphas[alpha_075_cut]-alpha[0]).reshape((-1,1,1,1)), weights=w_alphas[alpha_075_cut], axis=0)
dSigma_075 = np.average(dP_075_da.reshape((len(w_075),-1,1)) @ dP_075_da.reshape((len(w_075),1,-1)), weights=w_075, axis=0).reshape(*P_075.shape[1:],*P_075.shape[1:]).swapaxes(1,2)

# %%
P_075_avg = np.average(P_075, weights=w_075, axis=0)
P_075_cov = Sigma_075 + dSigma_075 * dalpha[0]**2
P_075_std = np.sqrt([np.diag(P_075_cov[0,0]), np.diag(P_075_cov[1,1])])

# %%
def const_prior(f, low=0., high=1.):
    return np.prod((f>=low)*(f<=high)/(high-low))

def inv_prior(f, low=0.01, high=1.):
    return np.prod((1/f)*(f>=low)*(f<=high)/np.log(high/low))

def gauss_prior(f, mean=0.3, inv_cov=np.diag(np.array([0.1,0.1])**(-2))):
    return np.exp(-(f-mean)@inv_cov@(f-mean)/2)*np.sqrt(np.linalg.det(inv_cov/2/np.pi))

# %%
(np.ones((2,3,1,4)) @ np.ones((2,3,4,4)) @ np.ones((2,3,4,1))).shape
# Out:
# (2, 3, 1, 1)

# %%
Z_samp.shape
# Out:
# (10, 7296, 194)

# %%
np.einsum('lmka,ija->ijklm', np.ones((2,3,4,5)), np.ones((6,7,5))).shape
# Out:
# (6, 7, 4, 2, 3)

# %%
np.einsum('lmkc,lnkd,ja,jb,iabcd->ijklmn',np.ones((2,3,4,5)), np.ones((2,3,4,5)), np.ones((6,7)), np.ones((6,7)), np.ones((8,7,7,5,5))).shape
# Out:
# (8, 6, 4, 2, 3, 3)

# %%
#H
#axis0 - Accumulation Model
#axis1 - Production Depth
#axis2 - Accumulation Depth
#axis3 - Time

#Z = np.einsum('iljk,k->ijkl', H[:,Prop.z>Prop.z_close], np.exp(Prop.lambd*Prop.t_int)*Prop.dt_int)
#axis0 - Accumulation Model
#axis1 - Accumulation Depth
#axis2 - Time
#axis3 - Production Depth

#S_mat
#axis0 - Accumulation Depth
#axis1 - Sample Depth

#Z_samp = (Prop.S_mat.T @ Z.T).T
#axis0 - Accumulation Model
#axis1 - Sample Depth
#axis2 - Time
#axis3 - Production Depth

#phi
#axis0 - CR History
#axis1 - Time

#P_avg
#axis0 - Production ModelSet
#axis1 - Production Mode
#axis2 - Production Depth

#f
#axis0 - f-factors
#axis1 - Production Mode

#C_pred = np.einsum('lmka,ija->ijklm', phi @ Z_samp, f @ P_avg)

#C_pred
#axis0 - Production ModelSet
#axis1 - f-factors
#axis2 - CR History
#axis3 - Accumulation Model
#axis4 - Sample Depth

#P_cov
# Production ModelSet
# Production Mode
# Production Mode
# Production Depth
# Production Depth
    
#C_pred_cov = np.einsum('lmkc,lnkd,ja,jb,iabcd->ijklmn',phi@Z_samp, phi@Z_samp, f, f, P_cov)

#C_pred_cov
#axis0 - Production ModelSet
#axis1 - f-factors
#axis2 - CR History
#axis3 - Accumulation Model
#axis4 - Sample Depth
#axis5 - Sample Depth

#dC = C_exp.reshape((-1,1,1,len(Prop.z_samp))) - C_pred.reshape((1,-1,1,len(Prop.z_samp)))
#C_cov = C_exp_cov.reshape((-1,1,C_exp_cov.shape[-2:])) + C_pred_cov.reshape((1,-1,C_pred_cov.shape[-2:]))
def log_L(dC, # Difference between observed and predicted 14CO
              #axis0 - Measurement
              #axis1 - Model
              #axis2 - N/A
              #axis3 - Sample Depth
          C_cov, # Total covariance (experiment + prediction) 
              #axis0 - Measurement
              #axis1 - Model
              #axis2 - Sample Depth
              #axis3 - Sample Depth
         ):
    return -np.sum(dC @ np.linalg.inv(C_cov) * dC, axis=(-2,-1))/2 - np.log(np.linalg.det(2*np.pi*C_cov))/2
# LogL
# axis0 - Measurement
# axis1 - Model

#logL = log_L(dC, C_cov)

#logp_f = logpf(f) * df?? # prior should be inverse to f
#logp_phi = logpphi(phi) * dphi?? # prior should be inverse to how wonky the flux looks
#logp = (logp_P.reshape((-1,1,1,1))+logp_f.reshape((1,-1,1,1))+logp_phi.reshape((1,1,-1,1))+logp_Z.reshape((1,1,1,-1))).reshape((1,-1))

#L = Likelihood(logL, logp)
def Likelihood(logL, # log Likelihood
                   #axis0 - Measurement
                   #axis1 - Model
               logp, # log Prior
                   #axis0 - N/A
                   #axis1 - Model
              ):
    return np.sum(np.exp(logL+logp), axis=-1)
# L
# axis0 - Measurement

# %%
phi = (Prop.t_int/-Prop.t_int_bins[0])*0. + 1
Z_0 = np.sum(Z, axis=1)
f = np.array([0.15,0.15])
C = (T(Z) @ phi) @ (T(P_075_avg)[Prop.z>Prop.z_close] @ f)
C_cov = (T(Z) @ phi) @ (f @ P_075_cov.T @ f)[Prop.z>Prop.z_close][:,Prop.z>Prop.z_close] @ (T(Z) @ phi).T
C_std = np.sqrt(np.diag(C_cov))
plt.fill_between(Prop.z_accum, C-2*C_std, C+2*C_std, alpha=0.2)
plt.plot(Prop.z_accum, C, label=r'MCEq Avg. w/ 2$\sigma$ ({:.3f}, {:.3f})'.format(*f))
#plt.plot(Prop.z_accum, (T(Z) @ phi) @ (T(P_cut_avg)[Prop.z>Prop.z_close,0]*f[0]), label=r'MCEq Avg. w/ 2$\sigma$ fast')
#plt.plot(Prop.z_accum, (T(Z) @ phi) @ (T(P_cut_avg)[Prop.z>Prop.z_close,1]*f[1]), label=r'MCEq Avg. w/ 2$\sigma$ neg')
f_H = np.array([0.084,0.068])
plt.plot(Prop.z_accum, Z_0 @ (T(P_14C[-1])[Prop.z>Prop.z_close] @ f_H), c='k', ls='--', label='Heisinger ({:.3f}, {:.3f})'.format(*f_H))

plt.xlabel('Depth [m]')
plt.ylabel(r'$^{14}$CO Concentration [molecules /g]')

plt.legend(loc='lower right')
plt.title(r'Predicted $^{14}$CO Concentration @ Dome C, $\alpha$'+'={:.2f}'.format(alphas[i]))
plt.show()

# %%
C_pred = (T(Z_samp) @ phi) @ (T(P_075_avg)[Prop.z>Prop.z_close] @ f)
C_pred_cov = (T(Z_samp) @ phi) @ (f @ P_075_cov.T @ f)[Prop.z>Prop.z_close][:,Prop.z>Prop.z_close] @ (T(Z_samp) @ phi).T
C_pred_std = np.sqrt(np.diag(C_pred_cov))

rel_err = 0.02

C_exp_true = np.random.multivariate_normal(C_pred, C_pred_cov)
s = np.random.normal(1., rel_err, len(C_exp_true))
C_exp = C_exp_true * s
C_exp_std = rel_err * C_exp
C_exp_cov = np.diag(C_exp_std**2)

plt.fill_between(Prop.z_accum, C-2*C_std, C+2*C_std, alpha=0.2)
plt.fill_between(Prop.z_accum, C-C_std, C+C_std, alpha=0.2)
plt.plot(Prop.z_accum, C, label=r'MCEq Avg. w/ 2$\sigma$ ({:.3f}, {:.3f})'.format(*f))
#plt.plot(Prop.z_accum, (T(Z) @ phi) @ (T(P_cut_avg)[Prop.z>Prop.z_close,0]*f[0]), label=r'MCEq Avg. w/ 2$\sigma$ fast')
#plt.plot(Prop.z_accum, (T(Z) @ phi) @ (T(P_cut_avg)[Prop.z>Prop.z_close,1]*f[1]), label=r'MCEq Avg. w/ 2$\sigma$ neg')
f_H = np.array([0.084,0.068])
#plt.plot(Prop.z_accum, Z_0 @ (T(P_14C[-1])[Prop.z>Prop.z_close] @ f_H), c='k', ls='--', label='Heisinger ({:.3f}, {:.3f})'.format(*f_H))
plt.plot(Prop.z_samp, C_exp_true, c='r', ls='--')
plt.errorbar(Prop.z_samp, C_exp, 2*C_exp_std, fmt='.', c='r', label=r'Test Obs. w/ 2$\sigma$ err (MCEq)')

plt.xlabel('Depth [m]')
plt.ylabel(r'$^{14}$CO Concentration [molecules /g]')

plt.legend(loc='lower right')
plt.title(r'Predicted $^{14}$CO Concentration @ Dome C, $\alpha$'+'={:.2f}'.format(alphas[i]))
plt.show()

Sigma_inv = np.linalg.inv(C_pred_cov + C_exp_cov)
chi2 = (C_pred-C_exp) @ Sigma_inv @ (C_pred-C_exp)
logL = -chi2/2 - np.log(np.linalg.det(2*np.pi*(C_pred_cov+C_exp_cov)))/2
print('chi^2_exp = {:.2f}'.format(np.sum(((s-1)/rel_err)**2)))
print('chi^2_prod = {:.2f}'.format((C_pred-C_exp_true) @ np.linalg.inv(C_pred_cov) @ (C_pred - C_exp_true)))
print('chi^2 = {:.2f}'.format(chi2))
print('logL = {:.2f}'.format(logL))
# Out:
# chi^2_exp = 20.18
# chi^2_prod = 13.10
# chi^2 = 12.97
# logL = -10.64

# %%
im = plt.imshow(C_cov/(C_std.reshape((-1,1)) * C_std.reshape((1,-1))), origin='lower', aspect='auto', interpolation='none', extent=(Prop.z_accum_bins[0], Prop.z_accum_bins[-1], Prop.z_accum_bins[0], Prop.z_accum_bins[-1]))
plt.colorbar(im)
plt.title(r'$^{14}$CO Production Uncertainty Correlations')
plt.xlabel('Sample Depth [m]')
plt.ylabel('Sample Depth [m]')
plt.show()

# %%
im = plt.imshow(P_cut_cov[0,0][Prop.z>Prop.z_close][:,Prop.z>Prop.z_close]/(P_cut_std[0][Prop.z>Prop.z_close].reshape((-1,1)) * P_cut_std[0][Prop.z>Prop.z_close].reshape((1,-1))), origin='lower', aspect='auto', interpolation='none', extent=(Prop.z_bins[Prop.z_bins>Prop.z_close][0], Prop.z_bins[-1], Prop.z_bins[Prop.z_bins>Prop.z_close][0], Prop.z_bins[-1]))
plt.colorbar(im)
plt.title(r'$^{14}$CO Production Uncertainty Correlations')
plt.xlabel('P_fast Depth [m]')
plt.ylabel('P_fast Depth [m]')
plt.show()

# %%
im = plt.imshow(P_cut_cov[1,1][Prop.z>Prop.z_close][:,Prop.z>Prop.z_close]/(P_cut_std[1][Prop.z>Prop.z_close].reshape((-1,1)) * P_cut_std[1][Prop.z>Prop.z_close].reshape((1,-1))), origin='lower', aspect='auto', interpolation='none', extent=(Prop.z_bins[Prop.z_bins>Prop.z_close][0], Prop.z_bins[-1], Prop.z_bins[Prop.z_bins>Prop.z_close][0], Prop.z_bins[-1]))
plt.colorbar(im)
plt.title(r'$^{14}$CO Production Uncertainty Correlations')
plt.xlabel('P_neg Depth [m]')
plt.ylabel('P_neg Depth [m]')
plt.show()

# %%
im = plt.imshow(P_cut_cov[0,1][Prop.z>Prop.z_close][:,Prop.z>Prop.z_close]/(P_cut_std[0][Prop.z>Prop.z_close].reshape((-1,1)) * P_cut_std[1][Prop.z>Prop.z_close].reshape((1,-1))), origin='lower', aspect='auto', interpolation='none', extent=(Prop.z_bins[Prop.z_bins>Prop.z_close][0], Prop.z_bins[-1], Prop.z_bins[Prop.z_bins>Prop.z_close][0], Prop.z_bins[-1]))
plt.colorbar(im)
plt.title(r'$^{14}$CO Production Uncertainty Correlations')
plt.xlabel('P_fast Depth [m]')
plt.ylabel('P_neg Depth [m]')
plt.show()

# %%
P_cov.shape
# Out:
# (2, 2, 255, 255)

# %%
Z.shape
# Out:
# (10, 7296, 194)
